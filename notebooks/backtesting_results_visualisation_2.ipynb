# %%
import seaborn as sns
import pandas as pd
import yfinance as yf
import math
import ast
import json
import statistics
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import warnings
import sys
sys.path.append('../src')
from functions import stock_selection_weight_allocation, adjust_portfolio, calculate_shares_to_buy_with_prices
warnings.filterwarnings("ignore")

# %%
# Load the data
data_path = '../data/final_backtesting_summary.csv'  # Update this path to your CSV file location
df = pd.read_csv(data_path, index_col=0)

# %%
df = df[df['Stock_Selection_Method'].isin([1,3,5,7,9,11,13,15])]

# %%
df.loc[df['Stock_Selection_Method'] == 3, 'Stock_Selection_Method'] = 2
df.loc[df['Stock_Selection_Method'] == 5, 'Stock_Selection_Method'] = 3
df.loc[df['Stock_Selection_Method'] == 7, 'Stock_Selection_Method'] = 4
df.loc[df['Stock_Selection_Method'] == 9, 'Stock_Selection_Method'] = 5
df.loc[df['Stock_Selection_Method'] == 11, 'Stock_Selection_Method'] = 6
df.loc[df['Stock_Selection_Method'] == 13, 'Stock_Selection_Method'] = 7
df.loc[df['Stock_Selection_Method'] == 15, 'Stock_Selection_Method'] = 8

# %%
df['Strategy_Combination'] = df['Stock_Selection_Method'].astype(str) + '_' + df['Weight_Allocation_Method'].astype(str) + '_' + df['Backtest_Version'].astype(str)

# %%
cols = ['Strategy_Combination'] + [col for col in df.columns if col != 'Strategy_Combination']
df = df[cols]

# %%
df_backup = df.copy()

# %%
df
# Out:
#     Strategy_Combination  Stock_Selection_Method  Weight_Allocation_Method  \
# 0                  7_8_1                       7                         8
# 9                  7_9_1                       7                         9
# 10                8_10_1                       8                        10
# 11                 6_9_1                       6                         9
# 16                 6_8_1                       6                         8
# ..                   ...                     ...                       ...
# 169              1_10_10                       1                        10
# 170              1_11_10                       1                        11
# 171               8_3_10                       8                         3
# 174               6_7_10                       6                         7
# 175               7_5_10                       7                         5
#
#      Total_Return  CAGR_4Y  CAGR_3Y  CAGR_2Y  CAGR_1Y  Positive_Return_Count  \
# 0           10.69     0.81     0.68     0.56     1.24                     12
# 9            7.61     0.66     0.58     0.58     1.18                     11
# 10          10.50     0.80     0.50     0.43     1.14                     33
# 11           6.25     0.58     0.36     0.25     1.17                     31
# 16           6.15     0.57     0.43     0.31     1.05                     31
# ..            ...      ...      ...      ...      ...                    ...
# 169          4.39     0.45     0.40     0.42     0.80                     11
# 170          4.35     0.44     0.42     0.40     0.74                     10
# 171          5.04     0.50     0.20     0.01     0.63                     26
# 174          4.50     0.46     0.45     0.33     0.23                     34
# 175         18.46     1.07     0.32     0.07     0.59                     10
#
#      Negative_Return_Count  Sum_Positive_Return  Sum_Negative_Return  \
# 0                        4                 3.74                -0.66
# 9                        5                 3.20                -0.61
# 10                      15                 3.76                -1.01
# 11                      17                 3.38                -1.21
# 16                      17                 3.15                -1.05
# ..                     ...                  ...                  ...
# 169                      5                 2.36                -0.54
# 170                      6                 2.31                -0.53
# 171                     22                 4.88                -2.36
# 174                     14                 2.48                -0.78
# 175                      6                 9.68                -1.02
#
#      Variance_4Y  Variance_3Y  Variance_2Y  Variance_1Y  Success_Rate  \
# 0         0.0815       0.0521       0.0714       0.0305          0.75
# 9         0.0643       0.0495       0.0670       0.0324          0.69
# 10        0.0811       0.0296       0.0390       0.0141          0.69
# 11        0.0616       0.0396       0.0446       0.0333          0.65
# 16        0.0386       0.0240       0.0323       0.0271          0.65
# ..           ...          ...          ...          ...           ...
# 169       0.0408       0.0377       0.0582       0.0911          0.69
# 170       0.0345       0.0331       0.0486       0.0769          0.62
# 171       0.3413       0.0525       0.0552       0.0679          0.54
# 174       0.0251       0.0073       0.0086       0.0117          0.71
# 175       3.3970       0.0592       0.0478       0.0471          0.62
#
#      Backtest_Version Rebalance
# 0                   1        3m
# 9                   1        3m
# 10                  1        1m
# 11                  1        1m
# 16                  1        1m
# ..                ...       ...
# 169                10        3m
# 170                10        3m
# 171                10        1m
# 174                10        1m
# 175                10        3m
#
# [880 rows x 19 columns]

# %%
stock_selection_methods_to_consider = []
weight_allocation_methods_to_consider = []
backtesting_versions_to_consider = []

# %%
max_success_rate = max(list(df['Success_Rate']))
df_max_success_rate = df[df['Success_Rate']==max_success_rate]

# %%
max_return_max_success_rate = max(list(df_max_success_rate['CAGR_4Y']))
df_max_return_max_success_rate = df_max_success_rate[df_max_success_rate['CAGR_4Y']==max_return_max_success_rate]

for i in range(len(df_max_return_max_success_rate)):
    stock_selection_methods_to_consider.append(df_max_return_max_success_rate['Stock_Selection_Method'].iloc[i])
    weight_allocation_methods_to_consider.append(df_max_return_max_success_rate['Weight_Allocation_Method'].iloc[i])
    backtesting_versions_to_consider.append(df_max_return_max_success_rate['Backtest_Version'].iloc[i])

print('Strategies with the maximum 4 year CAGR out of the strategies with the maximum success rate:')
df_max_return_max_success_rate
# Out:
# Strategies with the maximum 4 year CAGR out of the strategies with the maximum success rate:
#     Strategy_Combination  Stock_Selection_Method  Weight_Allocation_Method  \
# 149                7_7_5                       7                         7
# 161                7_6_5                       7                         6
#
#      Total_Return  CAGR_4Y  CAGR_3Y  CAGR_2Y  CAGR_1Y  Positive_Return_Count  \
# 149           9.5     0.76     0.74     0.64     1.28                     14
# 161           9.5     0.76     0.74     0.64     1.28                     14
#
#      Negative_Return_Count  Sum_Positive_Return  Sum_Negative_Return  \
# 149                      2                 3.12                -0.38
# 161                      2                 3.12                -0.38
#
#      Variance_4Y  Variance_3Y  Variance_2Y  Variance_1Y  Success_Rate  \
# 149       0.0452       0.0298       0.0248         0.02          0.88
# 161       0.0452       0.0298       0.0248         0.02          0.88
#
#      Backtest_Version Rebalance
# 149                 5        3m
# 161                 5        3m

# %%
min_variance_max_success_rate = min(list(df_max_success_rate['Variance_4Y']))
df_min_variance_max_success_rate = df_max_success_rate[df_max_success_rate['Variance_4Y']==min_variance_max_success_rate]

for i in range(len(df_min_variance_max_success_rate)):
    stock_selection_methods_to_consider.append(df_min_variance_max_success_rate['Stock_Selection_Method'].iloc[i])
    weight_allocation_methods_to_consider.append(df_min_variance_max_success_rate['Weight_Allocation_Method'].iloc[i])
    backtesting_versions_to_consider.append(df_min_variance_max_success_rate['Backtest_Version'].iloc[i])

print('Strategies with the minimum 4 year variance out of the strategies with the maximum success rate:')
df_min_variance_max_success_rate
# Out:
# Strategies with the minimum 4 year variance out of the strategies with the maximum success rate:
#     Strategy_Combination  Stock_Selection_Method  Weight_Allocation_Method  \
# 149                7_7_5                       7                         7
# 161                7_6_5                       7                         6
#
#      Total_Return  CAGR_4Y  CAGR_3Y  CAGR_2Y  CAGR_1Y  Positive_Return_Count  \
# 149           9.5     0.76     0.74     0.64     1.28                     14
# 161           9.5     0.76     0.74     0.64     1.28                     14
#
#      Negative_Return_Count  Sum_Positive_Return  Sum_Negative_Return  \
# 149                      2                 3.12                -0.38
# 161                      2                 3.12                -0.38
#
#      Variance_4Y  Variance_3Y  Variance_2Y  Variance_1Y  Success_Rate  \
# 149       0.0452       0.0298       0.0248         0.02          0.88
# 161       0.0452       0.0298       0.0248         0.02          0.88
#
#      Backtest_Version Rebalance
# 149                 5        3m
# 161                 5        3m

# %%
max_return = max(list(df['CAGR_4Y']))
df_max_return = df[df['CAGR_4Y']==max_return]

for i in range(len(df_max_return)):
    stock_selection_methods_to_consider.append(df_max_return['Stock_Selection_Method'].iloc[i])
    weight_allocation_methods_to_consider.append(df_max_return['Weight_Allocation_Method'].iloc[i])
    backtesting_versions_to_consider.append(df_max_return['Backtest_Version'].iloc[i])

df_max_return
# Out:
#    Strategy_Combination  Stock_Selection_Method  Weight_Allocation_Method  \
# 58               4_3_10                       4                         3
#
#     Total_Return  CAGR_4Y  CAGR_3Y  CAGR_2Y  CAGR_1Y  Positive_Return_Count  \
# 58         41.83     1.54     0.92      0.4     0.94                     34
#
#     Negative_Return_Count  Sum_Positive_Return  Sum_Negative_Return  \
# 58                     14                 5.19                -0.82
#
#     Variance_4Y  Variance_3Y  Variance_2Y  Variance_1Y  Success_Rate  \
# 58       0.1796        0.079       0.0369       0.0262          0.71
#
#     Backtest_Version Rebalance
# 58                10        1m

# %%
min_variance = min(list(df['Variance_4Y']))
df_min_variance = df[df['Variance_4Y']==min_variance]

for i in range(len(df_min_variance)):
    stock_selection_methods_to_consider.append(df_min_variance['Stock_Selection_Method'].iloc[i])
    weight_allocation_methods_to_consider.append(df_min_variance['Weight_Allocation_Method'].iloc[i])
    backtesting_versions_to_consider.append(df_min_variance['Backtest_Version'].iloc[i])

df_min_variance
# Out:
#    Strategy_Combination  Stock_Selection_Method  Weight_Allocation_Method  \
# 36                5_6_5                       5                         6
# 41                5_7_5                       5                         7
#
#     Total_Return  CAGR_4Y  CAGR_3Y  CAGR_2Y  CAGR_1Y  Positive_Return_Count  \
# 36          2.67     0.28     0.29     0.19     0.47                     12
# 41          2.67     0.28     0.29     0.19     0.47                     12
#
#     Negative_Return_Count  Sum_Positive_Return  Sum_Negative_Return  \
# 36                      4                 1.55                -0.43
# 41                      4                 1.55                -0.43
#
#     Variance_4Y  Variance_3Y  Variance_2Y  Variance_1Y  Success_Rate  \
# 36       0.0152       0.0128       0.0164       0.0125          0.75
# 41       0.0152       0.0128       0.0164       0.0125          0.75
#
#     Backtest_Version Rebalance
# 36                 5        3m
# 41                 5        3m

# %%
min_success_rate = min(list(df['Success_Rate']))

df[df['Success_Rate']==min_success_rate]
# Out:
#     Strategy_Combination  Stock_Selection_Method  Weight_Allocation_Method  \
# 127                6_3_8                       6                         3
#
#      Total_Return  CAGR_4Y  CAGR_3Y  CAGR_2Y  CAGR_1Y  Positive_Return_Count  \
# 127          4.09     0.42     0.36     0.16     0.25                     23
#
#      Negative_Return_Count  Sum_Positive_Return  Sum_Negative_Return  \
# 127                     25                 3.51                -1.67
#
#      Variance_4Y  Variance_3Y  Variance_2Y  Variance_1Y  Success_Rate  \
# 127       0.0818       0.0386       0.0371       0.0084          0.48
#
#      Backtest_Version Rebalance
# 127                 8        1m

# %%
# Calculate averages for CAGR, Variance, and Success Rate
avg_cagr_4y_by_stock_selection = df.groupby('Stock_Selection_Method')['CAGR_4Y'].mean()
avg_cagr_4y_by_weight_allocation = df.groupby('Weight_Allocation_Method')['CAGR_4Y'].mean()
avg_cagr_4y_by_rebalance = df.groupby('Rebalance')['CAGR_4Y'].mean()
avg_cagr_4y_by_backtest_version = df.groupby('Backtest_Version')['CAGR_4Y'].mean()

avg_variance_4y_by_stock_selection = df.groupby('Stock_Selection_Method')['Variance_4Y'].mean()
avg_variance_4y_by_weight_allocation = df.groupby('Weight_Allocation_Method')['Variance_4Y'].mean()
avg_variance_4y_by_rebalance = df.groupby('Rebalance')['Variance_4Y'].mean()
avg_variance_4y_by_backtest_version = df.groupby('Backtest_Version')['Variance_4Y'].mean()

success_rate_by_stock_selection = df.groupby('Stock_Selection_Method')['Success_Rate'].mean()
success_rate_by_weight_allocation = df.groupby('Weight_Allocation_Method')['Success_Rate'].mean()
success_rate_by_rebalance = df.groupby('Rebalance')['Success_Rate'].mean()
success_rate_by_backtest_version = df.groupby('Backtest_Version')['Success_Rate'].mean()

# %%
# Identify top and bottom categories for density plots
top_cagr_stock_method = avg_cagr_4y_by_stock_selection.nlargest(1).index.tolist()
top_cagr_weight_method = avg_cagr_4y_by_weight_allocation.nlargest(1).index.tolist()
top_version_cagr = avg_cagr_4y_by_backtest_version.nlargest(1).index.tolist()

bottom_variance_stock_method = avg_variance_4y_by_stock_selection.nsmallest(1).index.tolist()
bottom_variance_weight_method = avg_variance_4y_by_weight_allocation.nsmallest(1).index.tolist()
bottom_version_variance = avg_variance_4y_by_backtest_version.nsmallest(1).index.tolist()

top_success_rate_stock_method = success_rate_by_stock_selection.nlargest(1).index.tolist()
top_success_rate_weight_method = success_rate_by_weight_allocation.nlargest(1).index.tolist()
top_version_success_rate = success_rate_by_backtest_version.nlargest(1).index.tolist()

stock_selection_methods_to_consider += top_cagr_stock_method + bottom_variance_stock_method + top_success_rate_stock_method
weight_allocation_methods_to_consider += top_cagr_weight_method + bottom_variance_weight_method + top_success_rate_weight_method
backtesting_versions_to_consider += top_version_cagr + bottom_version_variance + top_version_success_rate

# %%
stock_selection_methods_to_consider = list(set(stock_selection_methods_to_consider))
weight_allocation_methods_to_consider = list(set(weight_allocation_methods_to_consider))
backtesting_versions_to_consider = list(set(backtesting_versions_to_consider))

stock_selection_methods_to_consider, weight_allocation_methods_to_consider, backtesting_versions_to_consider
# Out:
# ([3, 4, 5, 7, 8], [1, 3, 4, 6, 7], [10, 3, 4, 5])

# %%
def create_bar_graphs(data, title, xlabel, ylabel):
    plt.figure(figsize=(10, 6))
    
    data = pd.DataFrame(data).reset_index()
    data.columns = [xlabel, ylabel]
    data = data.reset_index(drop=True)
    data_sorted = data.sort_values(by=ylabel, ascending=False)

    sns.barplot(x=data_sorted[xlabel], y=ylabel, data=data_sorted, palette="viridis", order=data_sorted[xlabel])
    # sns.barplot(x=xlabel, y=ylabel, data=data, palette="viridis")
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45)
    plt.savefig(f'../backtesting_results/graphs_2/{title}.png', dpi=300)
    plt.show()

# %%
# Function to plot density curves with updated colors
def plot_density_curves_for_comparison(data, ids, metric, title, xlabel, ylabel, category_label):
    plt.figure(figsize=(12, 6))
    colors = sns.color_palette("dark", n_colors=len(ids))  # Use a dark color palette for clarity
    for i, id in enumerate(ids):
        subset = data[data[category_label] == id]
        sns.kdeplot(subset[metric], color=colors[i % len(colors)], label=f'{category_label} {id}', bw_adjust=0.5)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    if metric.startswith('Variance'):
        plt.xlim(-0.2, 0.5)
    plt.savefig(f'../backtesting_results/graphs_2/{title}.png', dpi=300)
    plt.show()

# %%
create_bar_graphs(avg_cagr_4y_by_stock_selection, 'Average 4Y CAGR by Stock Selection Method', 'Stock Selection Method', 'Average 4Y CAGR')
create_bar_graphs(avg_cagr_4y_by_weight_allocation, 'Average 4Y CAGR by Weight Allocation Method', 'Weight Allocation Method', 'Average 4Y CAGR')
create_bar_graphs(avg_cagr_4y_by_rebalance, 'Average 4Y CAGR by Rebalancing Period', 'Rebalancing Period', 'Average 4Y CAGR')
create_bar_graphs(avg_cagr_4y_by_backtest_version, 'Average 4Y CAGR by Backtest Version', 'Backtest Version', 'Average 4Y CAGR')

# %%
create_bar_graphs(avg_variance_4y_by_stock_selection, 'Average 4Y Variance by Stock Selection Method', 'Stock Selection Method', 'Average 4Y Variance')
create_bar_graphs(avg_variance_4y_by_weight_allocation, 'Average 4Y Variance by Weight Allocation Method', 'Weight Allocation Method', 'Average 4Y Variance')
create_bar_graphs(avg_variance_4y_by_rebalance, 'Average 4Y Variance by Rebalancing Period', 'Rebalancing Period', 'Average 4Y Variance')
create_bar_graphs(avg_variance_4y_by_backtest_version, 'Average 4Y Variance by Backtest Version', 'Backtest Version', 'Average 4Y Variance')

# %%
create_bar_graphs(success_rate_by_stock_selection, 'Success Rate by Stock Selection Method', 'Stock Selection Method', 'Success Rate')
create_bar_graphs(success_rate_by_weight_allocation, 'Success Rate by Weight Allocation Method', 'Weight Allocation Method', 'Success Rate')
create_bar_graphs(success_rate_by_rebalance, 'Success Rate by Rebalancing Period', 'Rebalancing Period', 'Success Rate')
create_bar_graphs(success_rate_by_backtest_version, 'Success Rate by Backtest Version', 'Backtest Version', 'Success Rate')

# %%
plot_density_curves_for_comparison(df, stock_selection_methods_to_consider, 'CAGR_4Y', 'Density of 4Y CAGR by Select Stock Selection Methods', '4Y CAGR', 'Density', 'Stock_Selection_Method')
plot_density_curves_for_comparison(df, weight_allocation_methods_to_consider, 'CAGR_4Y', 'Density of 4Y CAGR by Select Weight Allocation Methods', '4Y CAGR', 'Density', 'Weight_Allocation_Method')
plot_density_curves_for_comparison(df, df['Rebalance'].unique(), 'CAGR_4Y', 'Density of 4Y CAGR by Rebalancing Periods', '4Y CAGR', 'Density', 'Rebalance')
plot_density_curves_for_comparison(df, backtesting_versions_to_consider, 'CAGR_4Y', 'Density of 4Y CAGR by Select Backtest Versions', '4Y CAGR', 'Density', 'Backtest_Version')

# %%
plot_density_curves_for_comparison(df, stock_selection_methods_to_consider, 'Variance_4Y', 'Density of 4Y Variance by Select Stock Selection Methods', '4Y Variance', 'Density', 'Stock_Selection_Method')
plot_density_curves_for_comparison(df, weight_allocation_methods_to_consider, 'Variance_4Y', 'Density of 4Y Variance by Select Weight Allocation Methods', '4Y Variance', 'Density', 'Weight_Allocation_Method')
plot_density_curves_for_comparison(df, df['Rebalance'].unique(), 'Variance_4Y', 'Density of 4Y Variance by Rebalancing Periods', '4Y Variance', 'Density', 'Rebalance')
plot_density_curves_for_comparison(df, backtesting_versions_to_consider, 'Variance_4Y', 'Density of 4Y Variance by Select Backtest Versions', '4Y Variance', 'Density', 'Backtest_Version')

# %%
plot_density_curves_for_comparison(df, stock_selection_methods_to_consider, 'Success_Rate', 'Density of Success Rates by Select Stock Selection Methods', 'Success Rate', 'Density', 'Stock_Selection_Method')
plot_density_curves_for_comparison(df, weight_allocation_methods_to_consider, 'Success_Rate', 'Density of Success Rates by Select Weight Allocation Methods', 'Success Rate', 'Density', 'Weight_Allocation_Method')
plot_density_curves_for_comparison(df, df['Rebalance'].unique(), 'Success_Rate', 'Density of Success Rates by Rebalancing Periods', 'Success Rate', 'Density', 'Rebalance')
plot_density_curves_for_comparison(df, backtesting_versions_to_consider, 'Success_Rate', 'Density of Success Rates by Select Backtest Versions', 'Success Rate', 'Density', 'Backtest_Version')

# %%
all_stocks_df = pd.read_csv('../data/all_stock_data.csv', index_col=0)
all_stocks_df.index = pd.to_datetime(all_stocks_df.index)

# %%
final_symbols = list(all_stocks_df.columns)

# %%
govt_bond_df = pd.read_csv('../data/India 10-Year Bond Yield Historical Data.csv')
govt_bond_df = govt_bond_df[['Date','Price']]
govt_bond_df.index = govt_bond_df['Date']
govt_bond_df = govt_bond_df.drop('Date', axis=1)
govt_bond_df.index = pd.to_datetime(govt_bond_df.index)

# %%
def get_dates_in_range(start_date, end_date, months):
    # Convert string dates to datetime objects
    start_date = datetime.strptime(start_date, '%Y-%m-%d')
    # Calculate end date by subtracting one month from the given end date
    end_date = datetime.strptime(end_date, '%Y-%m-%d') - relativedelta(months=months)
    
    # Generate a list of dates in the desired format
    date_list = []
    current_date = start_date
    while current_date <= end_date:
        date_list.append(current_date.strftime('%Y-%m-%d'))
        current_date += timedelta(days=1)
    
    return date_list

# %%
start_date = '2023-10-01'
end_date = '2024-03-23'

backtesting_buying_dates_for_1m_hold = get_dates_in_range(start_date, end_date, 1)
backtesting_buying_dates_for_1q_hold = get_dates_in_range(start_date, end_date, 3)

# %%
market_dates_ = list(all_stocks_df.index)
market_dates = []
for date in market_dates_:
    market_dates.append(str(date)[:10])

# %%
backtesting_buying_dates_for_1q_hold_ = []
for date in backtesting_buying_dates_for_1q_hold:
    if date in market_dates:
        backtesting_buying_dates_for_1q_hold_.append(date)

backtesting_buying_dates_for_1q_hold = backtesting_buying_dates_for_1q_hold_

backtesting_buying_dates_for_1q_hold, len(backtesting_buying_dates_for_1q_hold)
# Out:
# (['2023-10-03',
#   '2023-10-04',
#   '2023-10-05',
#   '2023-10-06',
#   '2023-10-09',
#   '2023-10-10',
#   '2023-10-11',
#   '2023-10-12',
#   '2023-10-13',
#   '2023-10-16',
#   '2023-10-17',
#   '2023-10-18',
#   '2023-10-19',
#   '2023-10-20',
#   '2023-10-23',
#   '2023-10-25',
#   '2023-10-26',
#   '2023-10-27',
#   '2023-10-30',
#   '2023-10-31',
#   '2023-11-01',
#   '2023-11-02',
#   '2023-11-03',
#   '2023-11-06',
#   '2023-11-07',
#   '2023-11-08',
#   '2023-11-09',
#   '2023-11-10',
#   '2023-11-13',
#   '2023-11-15',
#   '2023-11-16',
#   '2023-11-17',
#   '2023-11-20',
#   '2023-11-21',
#   '2023-11-22',
#   '2023-11-23',
#   '2023-11-24',
#   '2023-11-28',
#   '2023-11-29',
#   '2023-11-30',
#   '2023-12-01',
#   '2023-12-04',
#   '2023-12-05',
#   '2023-12-06',
#   '2023-12-07',
#   '2023-12-08',
#   '2023-12-11',
#   '2023-12-12',
#   '2023-12-13',
#   '2023-12-14',
#   '2023-12-15',
#   '2023-12-18',
#   '2023-12-19',
#   '2023-12-20',
#   '2023-12-21',
#   '2023-12-22'],
#  56)

# %%
backtesting_buying_dates_for_1m_hold_ = []
for date in backtesting_buying_dates_for_1m_hold:
    if date in market_dates:
        backtesting_buying_dates_for_1m_hold_.append(date)

backtesting_buying_dates_for_1m_hold = backtesting_buying_dates_for_1m_hold_[:56]

backtesting_buying_dates_for_1m_hold, len(backtesting_buying_dates_for_1m_hold)
# Out:
# (['2023-10-03',
#   '2023-10-04',
#   '2023-10-05',
#   '2023-10-06',
#   '2023-10-09',
#   '2023-10-10',
#   '2023-10-11',
#   '2023-10-12',
#   '2023-10-13',
#   '2023-10-16',
#   '2023-10-17',
#   '2023-10-18',
#   '2023-10-19',
#   '2023-10-20',
#   '2023-10-23',
#   '2023-10-25',
#   '2023-10-26',
#   '2023-10-27',
#   '2023-10-30',
#   '2023-10-31',
#   '2023-11-01',
#   '2023-11-02',
#   '2023-11-03',
#   '2023-11-06',
#   '2023-11-07',
#   '2023-11-08',
#   '2023-11-09',
#   '2023-11-10',
#   '2023-11-13',
#   '2023-11-15',
#   '2023-11-16',
#   '2023-11-17',
#   '2023-11-20',
#   '2023-11-21',
#   '2023-11-22',
#   '2023-11-23',
#   '2023-11-24',
#   '2023-11-28',
#   '2023-11-29',
#   '2023-11-30',
#   '2023-12-01',
#   '2023-12-04',
#   '2023-12-05',
#   '2023-12-06',
#   '2023-12-07',
#   '2023-12-08',
#   '2023-12-11',
#   '2023-12-12',
#   '2023-12-13',
#   '2023-12-14',
#   '2023-12-15',
#   '2023-12-18',
#   '2023-12-19',
#   '2023-12-20',
#   '2023-12-21',
#   '2023-12-22'],
#  56)

# %%
# 1 - 1,2
# 2 - 3,4
# 3 - 5,6
# 4 - 7,8
# 5 - 9,10
# 6 - 11,12
# 7 - 13,14
# 8 - 15,16

# %%
# 1_6_7 - lowest cagr diff
# 4_7_5 - second lowest cagr diff
# 5_6_5 - lowest variance diff
# 5_6_7 - second lowest variance diff
# 8_1_4 - third lowest variance diff
# 3_11_3 - highest total cagr
# 3_10_3 - second highest total cagr
# 6_1_8 - lowest total variance
# 3_7_5 - second lowest total variance
# 1_6_9 - third lowest total variance

# %%
bt_v_list = [(1,1), (1,2), (2,1), (2,2), (0.5,0.5), (1,0.5), (0.5,1), (0.25,0.25), (0.5,0.25), (0.25,0.5)]
strategies_selected = [(13,7,5),(7,3,10),(9,7,5),(1,6,7),(7,7,5),(9,6,5),(9,6,7),(15,1,4),(5,11,3),(5,10,3),(11,1,8),(5,7,5),(1,6,9)]

# %%
def save_dict_to_json(data, filename):
    """
    Saves a dictionary to a JSON file.

    Parameters:
    - data (dict): The dictionary to save.
    - filename (str): The name of the file to save the dictionary to.
    """
    with open(filename, 'w') as f:
        json.dump(data, f, indent=4)

# %%
def load_json_to_dict(filename):
    """
    Loads JSON data from a file and returns it as a dictionary.

    Parameters:
    - filename (str): The name of the JSON file to read from.
    
    Returns:
    - dict: The dictionary containing the data read from the JSON file.
    """
    with open(filename, 'r') as f:
        data = json.load(f)
    return data

# %%
try:
    strategy_performance_dict = load_json_to_dict('../data/last_4_months_results.json')
    x = len(strategy_performance_dict)
except:
    strategy_performance_dict = {}
    x = 1

# Iterate over all strategy combinations
for strategy in strategies_selected[x-1:]:

    try:
        y = len(strategy_performance_dict[str(strategy)])
        transactions = strategy_performance_dict[str(strategy)]
    except:
        y = 0
        transactions = []

    stock_selection_strategy = strategy[0]
    weight_allocation_strategy = strategy[1]
    bt_v = strategy[2]
    last_x_years = bt_v_list[bt_v-1][0]
    last_x_years_opt = bt_v_list[bt_v-1][1]

    print(stock_selection_strategy, weight_allocation_strategy, bt_v, last_x_years, last_x_years_opt)

    if stock_selection_strategy in [1,2,5,6,9,10,13,14]:
        holding_period = '1q'
    elif stock_selection_strategy in [3,4,7,8,11,12,15,16]:
        holding_period = '1m'

    dates = backtesting_buying_dates_for_1m_hold if holding_period == '1m' else backtesting_buying_dates_for_1q_hold
    
    filters = 4

    if stock_selection_strategy in [1,2,5,6,9,10,13,14]:
        holding_period = '1q'
    elif stock_selection_strategy in [3,4,7,8,11,12,15,16]:
        holding_period = '1m'

    if stock_selection_strategy in [1,3,5,7,9,11,13,15]:
        returns_type = 'SR'
    elif stock_selection_strategy in [2,4,6,8,10,12,14,16]:
        returns_type = 'LR'

    if stock_selection_strategy in [1,2,3,4]:
        max_non_positive_returns_count = 15
    elif stock_selection_strategy in [5,6,7,8]:
        max_non_positive_returns_count = 10
    elif stock_selection_strategy in [9,10,11,12]:
        max_non_positive_returns_count = None
        filters = 3
    elif stock_selection_strategy in [13,14,15,16]:
        max_non_positive_returns_count = None
        filters = 2

    for buy_date in dates[y:]:

        portfolio, sell_date, best_method = stock_selection_weight_allocation(buy_date, holding_period, returns_type, max_non_positive_returns_count, weight_allocation_strategy, all_stocks_df, govt_bond_df, filters, last_x_years, last_x_years_opt)
        
        portfolio = adjust_portfolio(portfolio)

        current_cash = 100000.00

        # Calculate the allocated cash for each stock in the portfolio
        allocated_cash = {stock: current_cash * weight for stock, weight in portfolio.items()}

        # Adjust buy_date and sell_date to the nearest next available date in all_stocks_df
        adjusted_buy_date = all_stocks_df[all_stocks_df.index >= buy_date].index[0]
        try:
            adjusted_sell_date = all_stocks_df[all_stocks_df.index >= sell_date].index[0]
        except:
            adjusted_sell_date = all_stocks_df[all_stocks_df.index <= sell_date].index[-1]

        # Get stock prices on buying and selling dates
        buy_prices = all_stocks_df.loc[adjusted_buy_date, portfolio.keys()]
        sell_prices = all_stocks_df.loc[adjusted_sell_date, portfolio.keys()]

        # Calculate the number of shares bought for each stock
        buy_quantities = {stock: allocated_cash[stock] / buy_prices[stock] for stock in portfolio.keys()}

        # Calculate the value of the portfolio at selling date
        sell_values = {stock: sell_prices[stock] * buy_quantities[stock] for stock in portfolio.keys()}
        
        current_cash = round(sum(sell_values.values()),2)
        
        # Record the transaction details
        transaction = {
            'buy_date': str(adjusted_buy_date),
            'sell_date': str(adjusted_sell_date),
            'portfolio': portfolio,
            'sell_price': current_cash
        }

        transactions.append(transaction)
        strategy_performance_dict[str(strategy)] = transactions
        save_dict_to_json(strategy_performance_dict, '../data/last_4_months_results.json')
        
        print(f'Done {buy_date}')
# Out:
# 1 6 9 0.5 0.25

# %%
strategy_performance_dict = load_json_to_dict('../data/last_4_months_results.json')

# %%
strategy_performance_dict
# Out:
# {'(13, 7, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'GET&D.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'RESPONIND.NS': 0.125},
#    'sell_price': 125930.22},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'GET&D.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'TITAGARH.NS': 0.125},
#    'sell_price': 137392.35},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'BSE.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 137018.31},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HSCL.NS': 0.125},
#    'sell_price': 139297.2},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'HSCL.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 145573.77},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KAYNES.NS': 0.125,
#     'HSCL.NS': 0.125},
#    'sell_price': 138648.54},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 137472.96},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 139482.78},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KAYNES.NS': 0.125},
#    'sell_price': 133516.96},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'AGI.NS': 0.125},
#    'sell_price': 128178.68},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 135043.73},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MMTC.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 126861.43},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125},
#    'sell_price': 129910.48},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 124736.83},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 130778.28},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'GET&D.NS': 0.125},
#    'sell_price': 132800.09},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 139387.19},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 121207.82},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'ZENTEC.NS': 0.125},
#    'sell_price': 120733.0},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 132339.54},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 133867.56},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 133186.43},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 132945.57},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 124999.96},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 124528.34},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 126985.67},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'ITI.NS': 0.125},
#    'sell_price': 127342.05},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 121155.66},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 115729.76},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 120357.84},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125},
#    'sell_price': 116341.06},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125},
#    'sell_price': 115011.62},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 112081.5},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125},
#    'sell_price': 110638.05},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 114143.34},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'EMIL.NS': 0.125},
#    'sell_price': 114549.19},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 118786.75},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 115678.57},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125},
#    'sell_price': 118704.83},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 114458.94},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'RTNPOWER.NS': 0.125},
#    'sell_price': 113934.64},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 111799.81},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 112800.53},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 113272.8},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'SUZLON.NS': 0.125},
#    'sell_price': 117737.93},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 110462.4},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 114394.63},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 115731.78},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 98513.78},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 100649.82},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125},
#    'sell_price': 108178.65},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 103129.32},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 100684.19},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 107041.38},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 108377.93},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'SUZLON.NS': 0.125},
#    'sell_price': 107464.52}],
#  '(7, 3, 10)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2023-11-03 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GPIL.NS': 0.39603960396039606,
#     'JSL.NS': 0.2079207920792079},
#    'sell_price': 94130.26},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2023-11-06 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.2079207920792079,
#     'POLYCAB.NS': 0.39603960396039606},
#    'sell_price': 102256.15},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2023-11-06 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.39603960396039606,
#     'JSL.NS': 0.2079207920792079},
#    'sell_price': 105764.31},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2023-11-06 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.39603960396039606,
#     'JSL.NS': 0.2079207920792079},
#    'sell_price': 105058.5},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2023-11-09 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.2079207920792079,
#     'SAFARI.NS': 0.39603960396039606},
#    'sell_price': 103580.48},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2023-11-10 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.2079207920792079,
#     'SAFARI.NS': 0.39603960396039606},
#    'sell_price': 101224.69},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2023-11-13 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.2079207920792079,
#     'RECLTD.NS': 0.39603960396039606,
#     'SAFARI.NS': 0.39603960396039606},
#    'sell_price': 104359.46},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2023-11-13 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'RECLTD.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.2079207920792079},
#    'sell_price': 110557.18},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2023-11-13 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GPIL.NS': 0.2079207920792079,
#     'SAFARI.NS': 0.39603960396039606},
#    'sell_price': 100008.16},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2023-11-16 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.39603960396039606,
#     'AGI.NS': 0.39603960396039606,
#     'GABRIEL.NS': 0.2079207920792079},
#    'sell_price': 107575.67},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2023-11-17 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.39603960396039606,
#     'TORNTPOWER.NS': 0.2079207920792079},
#    'sell_price': 111570.99},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2023-11-20 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.39603960396039606,
#     'SAFARI.NS': 0.2079207920792079},
#    'sell_price': 111702.73},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2023-11-20 00:00:00',
#    'portfolio': {'APARINDS.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.39603960396039606,
#     'SAFARI.NS': 0.2079207920792079},
#    'sell_price': 110551.42},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2023-11-20 00:00:00',
#    'portfolio': {'GMDCLTD.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'AGI.NS': 0.2079207920792079},
#    'sell_price': 117649.3},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2023-11-23 00:00:00',
#    'portfolio': {'GABRIEL.NS': 0.39603960396039606,
#     'PFC.NS': 0.2079207920792079,
#     'RECLTD.NS': 0.39603960396039606},
#    'sell_price': 125100.74},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2023-11-28 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'GMDCLTD.NS': 0.2079207920792079},
#    'sell_price': 123911.97},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2023-11-28 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'GMDCLTD.NS': 0.2079207920792079},
#    'sell_price': 124280.82},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2023-11-28 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'GMDCLTD.NS': 0.2079207920792079},
#    'sell_price': 120998.17},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2023-11-30 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'ITI.NS': 0.39603960396039606,
#     'GMDCLTD.NS': 0.2079207920792079},
#    'sell_price': 114651.16},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2023-11-30 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.2079207920792079,
#     'AGI.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606},
#    'sell_price': 120967.51},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2023-12-01 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'GMDCLTD.NS': 0.2079207920792079},
#    'sell_price': 129641.52},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2023-12-04 00:00:00',
#    'portfolio': {'AGI.NS': 0.39603960396039606,
#     'ELECTCAST.NS': 0.39603960396039606,
#     'RECLTD.NS': 0.2079207920792079},
#    'sell_price': 118480.71},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2023-12-04 00:00:00',
#    'portfolio': {'GOKEX.NS': 0.39603960396039606,
#     'GRAVITA.NS': 0.39603960396039606,
#     'SAFARI.NS': 0.2079207920792079},
#    'sell_price': 112758.04},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2023-12-06 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'ANGELONE.NS': 0.2079207920792079},
#    'sell_price': 120625.5},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2023-12-07 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'FACT.NS': 0.2079207920792079},
#    'sell_price': 112708.19},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2023-12-08 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'GMDCLTD.NS': 0.2079207920792079},
#    'sell_price': 111241.25},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2023-12-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'GMDCLTD.NS': 0.2079207920792079},
#    'sell_price': 112208.28},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2023-12-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'FACT.NS': 0.39603960396039606,
#     'ELECTCAST.NS': 0.2079207920792079},
#    'sell_price': 113029.45},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2023-12-13 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'RECLTD.NS': 0.2079207920792079},
#    'sell_price': 107207.93},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2023-12-15 00:00:00',
#    'portfolio': {'GRAVITA.NS': 0.39603960396039606,
#     'SAFARI.NS': 0.2079207920792079,
#     'SAKSOFT.NS': 0.39603960396039606},
#    'sell_price': 91447.48},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2023-12-18 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'FACT.NS': 0.2079207920792079},
#    'sell_price': 98965.24},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2023-12-18 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'WELCORP.NS': 0.2079207920792079},
#    'sell_price': 94651.45},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2023-12-20 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'ANGELONE.NS': 0.39603960396039606,
#     'ELECTCAST.NS': 0.2079207920792079},
#    'sell_price': 104543.83},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2023-12-21 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'ELECTCAST.NS': 0.2079207920792079},
#    'sell_price': 101730.69},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2023-12-22 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'ELECTCAST.NS': 0.2079207920792079},
#    'sell_price': 108386.71},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2023-12-26 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'ELECTCAST.NS': 0.2079207920792079},
#    'sell_price': 107880.33},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2023-12-26 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'JINDALSAW.NS': 0.2079207920792079},
#    'sell_price': 104801.36},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2023-12-28 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'GABRIEL.NS': 0.2079207920792079},
#    'sell_price': 96576.72},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2023-12-29 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'THOMASCOOK.NS': 0.2079207920792079},
#    'sell_price': 92272.66},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-01-01 00:00:00',
#    'portfolio': {'HBLPOWER.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'THOMASCOOK.NS': 0.2079207920792079},
#    'sell_price': 102309.18},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-01-01 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'ELECTCAST.NS': 0.2079207920792079},
#    'sell_price': 94244.37},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'FACT.NS': 0.2079207920792079},
#    'sell_price': 105302.87},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'RECLTD.NS': 0.2079207920792079},
#    'sell_price': 100913.2},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'HBLPOWER.NS': 0.2079207920792079},
#    'sell_price': 103300.15},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.39603960396039606,
#     'HBLPOWER.NS': 0.2079207920792079},
#    'sell_price': 103275.03},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'HBLPOWER.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.2079207920792079},
#    'sell_price': 103246.18},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'HBLPOWER.NS': 0.39603960396039606,
#     'BSE.NS': 0.39603960396039606,
#     'SUZLON.NS': 0.2079207920792079},
#    'sell_price': 105296.13},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.39603960396039606,
#     'HBLPOWER.NS': 0.39603960396039606,
#     'SJVN.NS': 0.2079207920792079},
#    'sell_price': 105773.23},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'ELECON.NS': 0.39603960396039606,
#     'SOLARINDS.NS': 0.39603960396039606,
#     'VBL.NS': 0.2079207920792079},
#    'sell_price': 113462.0},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'ELECON.NS': 0.39603960396039606,
#     'KPITTECH.NS': 0.2079207920792079,
#     'SONATSOFTW.NS': 0.39603960396039606},
#    'sell_price': 106550.62},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'KPITTECH.NS': 0.39603960396039606,
#     'SHAREINDIA.NS': 0.2079207920792079,
#     'SOLARINDS.NS': 0.39603960396039606},
#    'sell_price': 102030.98},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'HBLPOWER.NS': 0.39603960396039606,
#     'NEWGEN.NS': 0.39603960396039606,
#     'GABRIEL.NS': 0.2079207920792079},
#    'sell_price': 105930.27},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'ANANTRAJ.NS': 0.39603960396039606,
#     'ELECON.NS': 0.2079207920792079,
#     'TRENT.NS': 0.39603960396039606},
#    'sell_price': 108624.59},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'HBLPOWER.NS': 0.39603960396039606,
#     'INOXWIND.NS': 0.39603960396039606,
#     'JYOTHYLAB.NS': 0.2079207920792079},
#    'sell_price': 107669.51},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'HBLPOWER.NS': 0.39603960396039606,
#     'INOXWIND.NS': 0.39603960396039606,
#     'JYOTHYLAB.NS': 0.2079207920792079},
#    'sell_price': 102018.92},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'ELECON.NS': 0.39603960396039606,
#     'RECLTD.NS': 0.39603960396039606,
#     'SONATSOFTW.NS': 0.2079207920792079},
#    'sell_price': 107643.1}],
#  '(9, 7, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 109678.91},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 110735.03},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 110218.81},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 110963.27},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 114430.09},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 114160.13},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 123342.08},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125},
#    'sell_price': 112919.59},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'NATCOPHARM.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125},
#    'sell_price': 117882.32},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 111607.99},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125},
#    'sell_price': 118045.89},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125},
#    'sell_price': 105735.23},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 105311.63},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 116100.14},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 124071.85},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 127388.55},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 128628.97},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 133685.76},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 128606.6},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125},
#    'sell_price': 140894.12},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 130244.06},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125},
#    'sell_price': 130478.76},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 121260.56},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 131996.64},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 118415.89},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125},
#    'sell_price': 109029.08},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 114488.24},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 107931.79},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 117680.23},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 110754.09},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 127794.93},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 112947.65},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125},
#    'sell_price': 134914.68},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 131518.64},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 133700.77},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125},
#    'sell_price': 124049.28},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LINDEINDIA.NS': 0.125,
#     'LEMONTREE.NS': 0.125},
#    'sell_price': 121567.72},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 103853.27},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 103581.44},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 115137.13},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 116276.61},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 118106.43},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KIRLOSBROS.NS': 0.125,
#     'KFINTECH.NS': 0.125},
#    'sell_price': 119535.84},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125},
#    'sell_price': 108261.86},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KFINTECH.NS': 0.125,
#     'KKCL.NS': 0.125,
#     'KAYNES.NS': 0.125},
#    'sell_price': 112770.8},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KFINTECH.NS': 0.125,
#     'KKCL.NS': 0.125},
#    'sell_price': 110093.95},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125},
#    'sell_price': 103932.7},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125},
#    'sell_price': 108736.1},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125},
#    'sell_price': 104660.82},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125},
#    'sell_price': 119209.35},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 108303.55},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 107679.63},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 111492.27},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 104513.1},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
# ...
#     'KEI.NS': 0.125,
#     'SCHAEFFLER.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'POWERMECH.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'SAFARI.NS': 0.125},
#    'sell_price': 113937.18},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'RAYMOND.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'SARDAEN.NS': 0.125},
#    'sell_price': 112002.37},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'KEI.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'GANESHHOUC.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'NHPC.NS': 0.125},
#    'sell_price': 113618.65},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'KEI.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'SAKSOFT.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'VBL.NS': 0.125,
#     'GRAVITA.NS': 0.125},
#    'sell_price': 113465.73},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'VBL.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'TDPOWERSYS.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 111904.14},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'USHAMART.NS': 0.125,
#     'ADANIENT.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'RATNAMANI.NS': 0.125},
#    'sell_price': 123987.16},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'KEI.NS': 0.125,
#     'USHAMART.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'VBL.NS': 0.125,
#     'INGERRAND.NS': 0.125,
#     'ADANIENT.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 113165.96},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'KSB.NS': 0.125,
#     'KEI.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 112105.1},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'VBL.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'HAL.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'INGERRAND.NS': 0.125,
#     'POWERGRID.NS': 0.125},
#    'sell_price': 126066.35},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'VBL.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'KEI.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'TITAGARH.NS': 0.125},
#    'sell_price': 117330.61},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'NAVA.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'VBL.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'INDIANB.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'SAFARI.NS': 0.125},
#    'sell_price': 112362.6},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NAVA.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'GRAVITA.NS': 0.125},
#    'sell_price': 120949.2},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NAVA.NS': 0.125,
#     'ELECON.NS': 0.125,
#     'KEI.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 116541.47},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'TVSMOTOR.NS': 0.125,
#     'BLS.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'GRAVITA.NS': 0.125},
#    'sell_price': 118490.24},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'LT.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 117449.95},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'ELECON.NS': 0.125,
#     'LT.NS': 0.125,
#     'BEL.NS': 0.125},
#    'sell_price': 126110.46},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'ELECON.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'TI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 121365.49},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'PRICOLLTD.NS': 0.125,
#     'KEI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'ELECON.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'NAVA.NS': 0.125,
#     'TI.NS': 0.125},
#    'sell_price': 125437.5},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'ELECON.NS': 0.125},
#    'sell_price': 118857.74},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'NAVA.NS': 0.125,
#     'BEL.NS': 0.125},
#    'sell_price': 127155.84},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'TDPOWERSYS.NS': 0.125,
#     'JWL.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'BEL.NS': 0.125},
#    'sell_price': 130040.36},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'TDPOWERSYS.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 127911.73},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'JWL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'NTPC.NS': 0.125},
#    'sell_price': 123809.58},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'JWL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'SARDAEN.NS': 0.125},
#    'sell_price': 116865.34},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'VBL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'SAKSOFT.NS': 0.125,
#     'TDPOWERSYS.NS': 0.125,
#     'SARDAEN.NS': 0.125},
#    'sell_price': 105237.35},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'USHAMART.NS': 0.125,
#     'VBL.NS': 0.125,
#     'TDPOWERSYS.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'KPITTECH.NS': 0.125},
#    'sell_price': 122054.41},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'RATNAMANI.NS': 0.125},
#    'sell_price': 123773.89},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'VBL.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'NTPC.NS': 0.125},
#    'sell_price': 119703.81},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'VBL.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 99059.09},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'VBL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'POWERGRID.NS': 0.125},
#    'sell_price': 110608.18},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'GRAVITA.NS': 0.125},
#    'sell_price': 104949.63},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'INDIANB.NS': 0.125},
#    'sell_price': 113471.85},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'VBL.NS': 0.125,
#     'ELECON.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'JSL.NS': 0.125},
#    'sell_price': 107106.34},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'PRICOLLTD.NS': 0.125,
#     'VBL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'GRAVITA.NS': 0.125},
#    'sell_price': 104530.72},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'ELECON.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'GRAVITA.NS': 0.125},
#    'sell_price': 110692.96},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'PRICOLLTD.NS': 0.125,
#     'KEI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'PGEL.NS': 0.125},
#    'sell_price': 109804.13},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'PRICOLLTD.NS': 0.125,
#     'KEI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'VBL.NS': 0.125,
#     'TI.NS': 0.125,
#     'ELECON.NS': 0.125},
#    'sell_price': 109813.68},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'ELECON.NS': 0.125},
#    'sell_price': 115378.03},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'NTPC.NS': 0.125},
#    'sell_price': 107225.82},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'BEL.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'NTPC.NS': 0.125},
#    'sell_price': 116598.39},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'VBL.NS': 0.125,
#     'KEI.NS': 0.125,
#     'BEL.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'PRICOLLTD.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'ELECON.NS': 0.125},
#    'sell_price': 115586.66},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'KEI.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'HAL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'VBL.NS': 0.125},
#    'sell_price': 114463.42},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'KEI.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'VBL.NS': 0.125},
#    'sell_price': 112202.66},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'KEI.NS': 0.125,
#     'SAKSOFT.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NTPC.NS': 0.125},
#    'sell_price': 97623.15},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'VBL.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'KPITTECH.NS': 0.125},
#    'sell_price': 90945.51},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'SARDAEN.NS': 0.125,
#     'TDPOWERSYS.NS': 0.125,
#     'KEI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'NHPC.NS': 0.125},
#    'sell_price': 101211.16},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'NHPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'TDPOWERSYS.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'GRAVITA.NS': 0.125},
#    'sell_price': 102027.93},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'KPITTECH.NS': 0.125,
#     'APARINDS.NS': 0.125},
#    'sell_price': 97905.38},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'VBL.NS': 0.125,
#     'NHPC.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'KEI.NS': 0.125,
#     'ANANTRAJ.NS': 0.125},
#    'sell_price': 102162.25},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'VBL.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'KEI.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'NTPC.NS': 0.125,
#     'RATNAMANI.NS': 0.125},
#    'sell_price': 96004.67},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'PGEL.NS': 0.125,
#     'SAFARI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'VBL.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'RATNAMANI.NS': 0.125,
#     'NTPC.NS': 0.125},
#    'sell_price': 95055.56},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'POWERGRID.NS': 0.125,
#     'PGEL.NS': 0.125,
#     'APARINDS.NS': 0.125,
#     'GRAVITA.NS': 0.125,
#     'POLYCAB.NS': 0.125,
#     'VBL.NS': 0.125},
#    'sell_price': 98343.96}]}

# %%
super_strategies = []
for strategy, result in strategy_performance_dict.items():
    print(strategy)
    count_n = 0
    count_p = 0
    for r in result:
        if r['sell_price'] <= 100000:
            count_n += 1
        else:
            count_p += 1

    print('Positie Return Count:', count_p)
    print('Negative Return Count:', count_n)
    if count_n/(count_n+count_p) <= 0.1:
        super_strategies.append(strategy)
    print('*****')
# Out:
# (13, 7, 5)
# Positie Return Count: 55
# Negative Return Count: 1
# *****
# (7, 3, 10)
# Positie Return Count: 49
# Negative Return Count: 7
# *****
# (9, 7, 5)
# Positie Return Count: 56
# Negative Return Count: 0
# *****
# (1, 6, 7)
# Positie Return Count: 49
# Negative Return Count: 7
# *****
# (7, 7, 5)
# Positie Return Count: 49
# Negative Return Count: 7
# *****
# (9, 6, 5)
# Positie Return Count: 56
# Negative Return Count: 0
# *****
# (9, 6, 7)
# Positie Return Count: 56
# Negative Return Count: 0
# *****
# (15, 1, 4)
# Positie Return Count: 56
# Negative Return Count: 0
# *****
# (5, 11, 3)
# Positie Return Count: 56
# Negative Return Count: 0
# *****
# (5, 10, 3)
# Positie Return Count: 56
# Negative Return Count: 0
# *****
# (11, 1, 8)
# Positie Return Count: 54
# Negative Return Count: 2
# *****
# (5, 7, 5)
# Positie Return Count: 49
# Negative Return Count: 7
# *****
# (1, 6, 9)
# Positie Return Count: 49
# Negative Return Count: 7
# *****

# %%
super_strategies_performance_dict = {}
for s in super_strategies:
    super_strategies_performance_dict[s] = strategy_performance_dict[s]

super_strategies_performance_dict
# Out:
# {'(13, 7, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'GET&D.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'RESPONIND.NS': 0.125},
#    'sell_price': 125930.22},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'GET&D.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'TITAGARH.NS': 0.125},
#    'sell_price': 137392.35},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'BSE.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 137018.31},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HSCL.NS': 0.125},
#    'sell_price': 139297.2},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'HSCL.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 145573.77},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KAYNES.NS': 0.125,
#     'HSCL.NS': 0.125},
#    'sell_price': 138648.54},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 137472.96},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 139482.78},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KAYNES.NS': 0.125},
#    'sell_price': 133516.96},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'AGI.NS': 0.125},
#    'sell_price': 128178.68},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 135043.73},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MMTC.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 126861.43},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125},
#    'sell_price': 129910.48},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 124736.83},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 130778.28},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'GET&D.NS': 0.125},
#    'sell_price': 132800.09},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 139387.19},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 121207.82},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'ZENTEC.NS': 0.125},
#    'sell_price': 120733.0},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 132339.54},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 133867.56},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 133186.43},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 132945.57},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 124999.96},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 124528.34},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 126985.67},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'ITI.NS': 0.125},
#    'sell_price': 127342.05},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 121155.66},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 115729.76},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 120357.84},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125},
#    'sell_price': 116341.06},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125},
#    'sell_price': 115011.62},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 112081.5},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125},
#    'sell_price': 110638.05},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 114143.34},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'EMIL.NS': 0.125},
#    'sell_price': 114549.19},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 118786.75},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 115678.57},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125},
#    'sell_price': 118704.83},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 114458.94},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'RTNPOWER.NS': 0.125},
#    'sell_price': 113934.64},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 111799.81},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 112800.53},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 113272.8},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'SUZLON.NS': 0.125},
#    'sell_price': 117737.93},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 110462.4},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 114394.63},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 115731.78},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 98513.78},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 100649.82},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125},
#    'sell_price': 108178.65},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 103129.32},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 100684.19},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 107041.38},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 108377.93},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'SUZLON.NS': 0.125},
#    'sell_price': 107464.52}],
#  '(9, 7, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 109678.91},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 110735.03},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 110218.81},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 110963.27},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 114430.09},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 114160.13},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 123342.08},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125},
#    'sell_price': 112919.59},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'NATCOPHARM.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125},
#    'sell_price': 117882.32},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 111607.99},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125},
#    'sell_price': 118045.89},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125},
#    'sell_price': 105735.23},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 105311.63},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 116100.14},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 124071.85},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 127388.55},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 128628.97},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 133685.76},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 128606.6},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125},
#    'sell_price': 140894.12},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 130244.06},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125},
#    'sell_price': 130478.76},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 121260.56},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 131996.64},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 118415.89},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125},
#    'sell_price': 109029.08},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 114488.24},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 107931.79},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 117680.23},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 110754.09},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 127794.93},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 112947.65},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125},
#    'sell_price': 134914.68},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 131518.64},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 133700.77},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125},
#    'sell_price': 124049.28},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LINDEINDIA.NS': 0.125,
#     'LEMONTREE.NS': 0.125},
#    'sell_price': 121567.72},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 103853.27},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 103581.44},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 115137.13},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 116276.61},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 118106.43},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KIRLOSBROS.NS': 0.125,
#     'KFINTECH.NS': 0.125},
#    'sell_price': 119535.84},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125},
#    'sell_price': 108261.86},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KFINTECH.NS': 0.125,
#     'KKCL.NS': 0.125,
#     'KAYNES.NS': 0.125},
#    'sell_price': 112770.8},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KFINTECH.NS': 0.125,
#     'KKCL.NS': 0.125},
#    'sell_price': 110093.95},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125},
#    'sell_price': 103932.7},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125},
#    'sell_price': 108736.1},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125},
#    'sell_price': 104660.82},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125},
#    'sell_price': 119209.35},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 108303.55},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 107679.63},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 111492.27},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 104513.1},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125},
#    'sell_price': 104169.63},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LANDMARK.NS': 0.125},
#    'sell_price': 104493.82}],
#  '(9, 6, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 109678.91},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 110735.03},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 110218.81},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 110963.27},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 114430.09},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 114160.13},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 123342.08},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125},
#    'sell_price': 112919.59},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'NATCOPHARM.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125},
#    'sell_price': 117882.32},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 111607.99},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125},
#    'sell_price': 118045.89},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125},
#    'sell_price': 105735.23},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 105311.63},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 116100.14},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 124071.85},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 127388.55},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 128628.97},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 133685.76},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 128606.6},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125},
#    'sell_price': 140894.12},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 130244.06},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125},
#    'sell_price': 130478.76},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 121260.56},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 131996.64},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 118415.89},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125},
#    'sell_price': 109029.08},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 114488.24},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 107931.79},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 117680.23},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 110754.09},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 127794.93},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 112947.65},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125},
#    'sell_price': 134914.68},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 131518.64},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 133700.77},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125},
#    'sell_price': 124049.28},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LINDEINDIA.NS': 0.125,
#     'LEMONTREE.NS': 0.125},
#    'sell_price': 121567.72},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 103853.27},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 103581.44},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
# ...
#     'CHENNPETRO.NS': 0.03333333333333334,
#     'JAICORPLTD.NS': 0.03333333333333334,
#     'KSB.NS': 0.03333333333333334,
#     'KALYANKJIL.NS': 0.03333333333333334,
#     'KARURVYSYA.NS': 0.03333333333333334,
#     'JKTYRE.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'LLOYDSENGG.NS': 0.03333333333333334,
#     'IPCALAB.NS': 0.03333333333333334,
#     'INOXWIND.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334},
#    'sell_price': 106997.22},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'CHENNPETRO.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'EMIL.NS': 0.03333333333333334,
#     'ELECTCAST.NS': 0.03333333333333334,
#     'LLOYDSENGG.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'SANOFI.NS': 0.03333333333333334,
#     'SHAREINDIA.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'KARURVYSYA.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334,
#     'SPANDANA.NS': 0.03333333333333334,
#     'BAJAJ-AUTO.NS': 0.03333333333333334,
#     'BSE.NS': 0.03333333333333334,
#     'KSB.NS': 0.03333333333333334,
#     'SUNTV.NS': 0.03333333333333334,
#     'SUZLON.NS': 0.03333333333333334,
#     'SOBHA.NS': 0.03333333333333334,
#     'DREAMFOLKS.NS': 0.03333333333333334,
#     'BOSCHLTD.NS': 0.03333333333333334,
#     'METROBRAND.NS': 0.03333333333333334,
#     'COALINDIA.NS': 0.03333333333333334,
#     'CONCORDBIO.NS': 0.03333333333333334,
#     'NEULANDLAB.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'NESTLEIND.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PNBHOUSING.NS': 0.03333333333333334,
#     'CENTURYTEX.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334},
#    'sell_price': 106146.09},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'INOXWIND.NS': 0.03333333333333334,
#     'BALKRISIND.NS': 0.03333333333333334,
#     'PNBHOUSING.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'IMFA.NS': 0.03333333333333334,
#     'CHENNPETRO.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'BSE.NS': 0.03333333333333334,
#     'COALINDIA.NS': 0.03333333333333334,
#     'ASTRAMICRO.NS': 0.03333333333333334,
#     'KARURVYSYA.NS': 0.03333333333333334,
#     'ASHOKA.NS': 0.03333333333333334,
#     'ARVIND.NS': 0.03333333333333334,
#     'HDFCAMC.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'CENTURYTEX.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'CMSINFO.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'LLOYDSENGG.NS': 0.03333333333333334,
#     'JAICORPLTD.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'IPCALAB.NS': 0.03333333333333334,
#     'METROBRAND.NS': 0.03333333333333334,
#     'INDIGO.NS': 0.03333333333333334,
#     'MOTILALOFS.NS': 0.03333333333333334,
#     'MCX.NS': 0.03333333333333334},
#    'sell_price': 105013.25},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'NMDC.NS': 0.03333333333333334,
#     'ISEC.NS': 0.03333333333333334,
#     'ARVIND.NS': 0.03333333333333334,
#     'ASHOKA.NS': 0.03333333333333334,
#     'KPITTECH.NS': 0.03333333333333334,
#     'ASTRAMICRO.NS': 0.03333333333333334,
#     'IMFA.NS': 0.03333333333333334,
#     'RAMKY.NS': 0.03333333333333334,
#     'MOTILALOFS.NS': 0.03333333333333334,
#     'DLF.NS': 0.03333333333333334,
#     'COLPAL.NS': 0.03333333333333334,
#     'LGBBROSLTD.NS': 0.03333333333333334,
#     'BSE.NS': 0.03333333333333334,
#     'BAJAJ-AUTO.NS': 0.03333333333333334,
#     'MCX.NS': 0.03333333333333334,
#     'METROBRAND.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'PHOENIXLTD.NS': 0.03333333333333334,
#     'CONCORDBIO.NS': 0.03333333333333334,
#     'IPCALAB.NS': 0.03333333333333334,
#     'PATANJALI.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'JKLAKSHMI.NS': 0.03333333333333334,
#     'PNBHOUSING.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'JYOTHYLAB.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'BLUESTARCO.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334},
#    'sell_price': 107072.72},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'WELSPUNLIV.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'JKLAKSHMI.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'BLUESTARCO.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'BSOFT.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PNBHOUSING.NS': 0.03333333333333334,
#     'IPCALAB.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'PATANJALI.NS': 0.03333333333333334,
#     'BRIGADE.NS': 0.03333333333333334,
#     'INOXWIND.NS': 0.03333333333333334,
#     'POLYMED.NS': 0.03333333333333334,
#     'PFC.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'PRIVISCL.NS': 0.03333333333333334,
#     'QUESS.NS': 0.03333333333333334,
#     'RECLTD.NS': 0.03333333333333334,
#     'RADICO.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'ICIL.NS': 0.03333333333333334,
#     'RKFORGE.NS': 0.03333333333333334,
#     'PHOENIXLTD.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334,
#     'GABRIEL.NS': 0.03333333333333334,
#     'NESTLEIND.NS': 0.03333333333333334,
#     'LGBBROSLTD.NS': 0.03333333333333334},
#    'sell_price': 105757.29},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.03333333333333334,
#     'HEROMOTOCO.NS': 0.03333333333333334,
#     'IRB.NS': 0.03333333333333334,
#     'IMFA.NS': 0.03333333333333334,
#     'INFIBEAM.NS': 0.03333333333333334,
#     'INOXWIND.NS': 0.03333333333333334,
#     'IPCALAB.NS': 0.03333333333333334,
#     'ECLERX.NS': 0.03333333333333334,
#     'JKLAKSHMI.NS': 0.03333333333333334,
#     'JAICORPLTD.NS': 0.03333333333333334,
#     'KPITTECH.NS': 0.03333333333333334,
#     'KARURVYSYA.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'MOIL.NS': 0.03333333333333334,
#     'LODHA.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'HBLPOWER.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'GNFC.NS': 0.03333333333333334,
#     'MEDANTA.NS': 0.03333333333333334,
#     'CHALET.NS': 0.03333333333333334,
#     'CHENNPETRO.NS': 0.03333333333333334,
#     'CUB.NS': 0.03333333333333334,
#     'COALINDIA.NS': 0.03333333333333334,
#     'COLPAL.NS': 0.03333333333333334,
#     'CONCORDBIO.NS': 0.03333333333333334,
#     'DLF.NS': 0.03333333333333334,
#     'DBL.NS': 0.03333333333333334,
#     'DREAMFOLKS.NS': 0.03333333333333334,
#     'EICHERMOT.NS': 0.03333333333333334},
#    'sell_price': 108774.13},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'GABRIEL.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'IRB.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'PFC.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'CONCORDBIO.NS': 0.03333333333333334,
#     'BSE.NS': 0.03333333333333334,
#     'RECLTD.NS': 0.03333333333333334,
#     'RADICO.NS': 0.03333333333333334,
#     'RAMKY.NS': 0.03333333333333334,
#     'KIRLOSENG.NS': 0.03333333333333334,
#     'IPCALAB.NS': 0.03333333333333334,
#     'CHALET.NS': 0.03333333333333334,
#     'HEROMOTOCO.NS': 0.03333333333333334,
#     'BAJAJ-AUTO.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334,
#     'NEULANDLAB.NS': 0.03333333333333334,
#     'CRISIL.NS': 0.03333333333333334,
#     'CMSINFO.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'INFIBEAM.NS': 0.03333333333333334,
#     'LODHA.NS': 0.03333333333333334,
#     'METROBRAND.NS': 0.03333333333333334,
#     'METROPOLIS.NS': 0.03333333333333334},
#    'sell_price': 106821.37},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.03333333333333334,
#     'CMSINFO.NS': 0.03333333333333334,
#     'MOIL.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'BRIGADE.NS': 0.03333333333333334,
#     'MAXHEALTH.NS': 0.03333333333333334,
#     'METROBRAND.NS': 0.03333333333333334,
#     'METROPOLIS.NS': 0.03333333333333334,
#     'BSOFT.NS': 0.03333333333333334,
#     'MCX.NS': 0.03333333333333334,
#     'CRISIL.NS': 0.03333333333333334,
#     'NMDC.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PNBHOUSING.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'PHOENIXLTD.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'NESTLEIND.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'KIRLOSENG.NS': 0.03333333333333334,
#     'KARURVYSYA.NS': 0.03333333333333334,
#     'ELECTCAST.NS': 0.03333333333333334,
#     'GLS.NS': 0.03333333333333334,
#     'MEDANTA.NS': 0.03333333333333334},
#    'sell_price': 106053.77},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.03333333333333334,
#     'MOIL.NS': 0.03333333333333334,
#     'CHENNPETRO.NS': 0.03333333333333334,
#     'CHAMBLFERT.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'CARYSIL.NS': 0.03333333333333334,
#     'METROBRAND.NS': 0.03333333333333334,
#     'MOTILALOFS.NS': 0.03333333333333334,
#     'MCX.NS': 0.03333333333333334,
#     'NBCC.NS': 0.03333333333333334,
#     'NMDC.NS': 0.03333333333333334,
#     'CUB.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'BSOFT.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PNBHOUSING.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'PATANJALI.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'PRSMJOHNSN.NS': 0.03333333333333334,
#     'BOSCHLTD.NS': 0.03333333333333334,
#     'COALINDIA.NS': 0.03333333333333334,
#     'COLPAL.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'MEDANTA.NS': 0.03333333333333334},
#    'sell_price': 106475.92},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.03333333333333334,
#     'MRF.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'CARYSIL.NS': 0.03333333333333334,
#     'METROBRAND.NS': 0.03333333333333334,
#     'CANBK.NS': 0.03333333333333334,
#     'MOTILALOFS.NS': 0.03333333333333334,
#     'MCX.NS': 0.03333333333333334,
#     'CMSINFO.NS': 0.03333333333333334,
#     'NMDC.NS': 0.03333333333333334,
#     'NESTLEIND.NS': 0.03333333333333334,
#     'NETWORK18.NS': 0.03333333333333334,
#     'GABRIEL.NS': 0.03333333333333334,
#     'BOSCHLTD.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'BSOFT.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'PATANJALI.NS': 0.03333333333333334,
#     'PERSISTENT.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'CHAMBLFERT.NS': 0.03333333333333334,
#     'RADICO.NS': 0.03333333333333334,
#     'CHENNPETRO.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334},
#    'sell_price': 108180.8},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.03333333333333334,
#     'JYOTHYLAB.NS': 0.03333333333333334,
#     'KPRMILL.NS': 0.03333333333333334,
#     'KARURVYSYA.NS': 0.03333333333333334,
#     'CRISIL.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'MAXHEALTH.NS': 0.03333333333333334,
#     'MOTILALOFS.NS': 0.03333333333333334,
#     'BRIGADE.NS': 0.03333333333333334,
#     'MCX.NS': 0.03333333333333334,
#     'NMDC.NS': 0.03333333333333334,
#     'BSOFT.NS': 0.03333333333333334,
#     'NETWORK18.NS': 0.03333333333333334,
#     'NEWGEN.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PTC.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'PATANJALI.NS': 0.03333333333333334,
#     'PERSISTENT.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'QUESS.NS': 0.03333333333333334,
#     'CDSL.NS': 0.03333333333333334,
#     'BAJAJ-AUTO.NS': 0.03333333333333334,
#     'JPASSOCIAT.NS': 0.03333333333333334,
#     'CHAMBLFERT.NS': 0.03333333333333334,
#     'ELECTCAST.NS': 0.03333333333333334,
#     'FACT.NS': 0.03333333333333334},
#    'sell_price': 109547.81},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.03333333333333334,
#     'MRPL.NS': 0.03333333333333334,
#     'CDSL.NS': 0.03333333333333334,
#     'MAXHEALTH.NS': 0.03333333333333334,
#     'MOTILALOFS.NS': 0.03333333333333334,
#     'MCX.NS': 0.03333333333333334,
#     'CANBK.NS': 0.03333333333333334,
#     'CRISIL.NS': 0.03333333333333334,
#     'NLCINDIA.NS': 0.03333333333333334,
#     'NMDC.NS': 0.03333333333333334,
#     'NESTLEIND.NS': 0.03333333333333334,
#     'NETWORK18.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'GICRE.NS': 0.03333333333333334,
#     'BRIGADE.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PTC.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'BSOFT.NS': 0.03333333333333334,
#     'PATANJALI.NS': 0.03333333333333334,
#     'PERSISTENT.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'NAM-INDIA.NS': 0.03333333333333334,
#     'QUESS.NS': 0.03333333333333334,
#     'CHAMBLFERT.NS': 0.03333333333333334,
#     'CHENNPETRO.NS': 0.03333333333333334,
#     'GLS.NS': 0.03333333333333334},
#    'sell_price': 107786.3},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.03333333333333334,
#     'PGEL.NS': 0.03333333333333334,
#     'PTC.NS': 0.03333333333333334,
#     'PAISALO.NS': 0.03333333333333334,
#     'BRIGADE.NS': 0.03333333333333334,
#     'PATANJALI.NS': 0.03333333333333334,
#     'PERSISTENT.NS': 0.03333333333333334,
#     'PHOENIXLTD.NS': 0.03333333333333334,
#     'JKLAKSHMI.NS': 0.03333333333333334,
#     'PFC.NS': 0.03333333333333334,
#     'BSOFT.NS': 0.03333333333333334,
#     'PCBL.NS': 0.03333333333333334,
#     'POWERGRID.NS': 0.03333333333333334,
#     'QUESS.NS': 0.03333333333333334,
#     'RECLTD.NS': 0.03333333333333334,
#     'RADICO.NS': 0.03333333333333334,
#     'RAILTEL.NS': 0.03333333333333334,
#     'RALLIS.NS': 0.03333333333333334,
#     'RAMKY.NS': 0.03333333333333334,
#     'L&TFH.NS': 0.03333333333333334,
#     'INDUSINDBK.NS': 0.03333333333333334,
#     'ROLEXRINGS.NS': 0.03333333333333334,
#     'ICIL.NS': 0.03333333333333334,
#     'PRESTIGE.NS': 0.03333333333333334,
#     'ORIENTCEM.NS': 0.03333333333333334,
#     'GLS.NS': 0.03333333333333334,
#     'JPASSOCIAT.NS': 0.03333333333333334,
#     'LODHA.NS': 0.03333333333333334,
#     'MAHSEAMLES.NS': 0.03333333333333334,
#     'CONCORDBIO.NS': 0.03333333333333334},
#    'sell_price': 103487.01}]}

# %%
strategy_sell_price_dict = {}
for strategy, portfolios in super_strategies_performance_dict.items():
    strategy_sell_price_dict[strategy] = []
    if len(portfolios) == 65:
        for portfolio in portfolios:
            strategy_sell_price_dict[strategy].append(round((portfolio['sell_price']/100000)-1,4))
    else:
        for portfolio in portfolios:
            return_quarterly = (portfolio['sell_price']/100000)-1
            strategy_sell_price_dict[strategy].append(round(((1+return_quarterly)**(1/3))-1,4))

# %%
for k,v in strategy_sell_price_dict.items():
    print(k, round(sum(v)/len(v),4))
# Out:
# (13, 7, 5) 0.0664
# (9, 7, 5) 0.0517
# (9, 6, 5) 0.0517
# (9, 6, 7) 0.0517
# (15, 1, 4) 0.0233
# (5, 11, 3) 0.0628
# (5, 10, 3) 0.0713
# (11, 1, 8) 0.0225

# %%
start_date = '2020-01-01'
end_date = '2024-03-23'

data = yf.download('^NSEI', start_date, end_date, interval="1d")
nifty50_data = data[['Adj Close']]
nifty50_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Adj Close
# Date
# 2020-01-01  12182.500000
# 2020-01-02  12282.200195
# 2020-01-03  12226.650391
# 2020-01-06  11993.049805
# 2020-01-07  12052.950195
# ...                  ...
# 2024-03-18  22055.699219
# 2024-03-19  21817.449219
# 2024-03-20  21839.099609
# 2024-03-21  22011.949219
# 2024-03-22  22096.750000
#
# [1048 rows x 1 columns]

# %%
nifty_returns_1m_periods = []

for date in backtesting_buying_dates_for_1m_hold:
    buy_date = date
    sell_date = str(datetime.strptime(buy_date, '%Y-%m-%d') + relativedelta(months=1))[:10]

    adjusted_buy_date = nifty50_data[nifty50_data.index >= buy_date].index[0]
    try:
        adjusted_sell_date = nifty50_data[nifty50_data.index >= sell_date].index[0]
    except:
        adjusted_sell_date = nifty50_data[nifty50_data.index <= sell_date].index[-1]

    buy_price = nifty50_data[nifty50_data.index == adjusted_buy_date].values[0][0]
    sell_price = nifty50_data[nifty50_data.index == adjusted_sell_date].values[0][0]

    returns = (sell_price/buy_price)-1

    nifty_returns_1m_periods.append(returns)

# %%
nifty_returns_1q_periods = []

for date in backtesting_buying_dates_for_1q_hold:
    buy_date = date
    sell_date = str(datetime.strptime(buy_date, '%Y-%m-%d') + relativedelta(months=3))[:10]

    adjusted_buy_date = nifty50_data[nifty50_data.index >= buy_date].index[0]
    try:
        adjusted_sell_date = nifty50_data[nifty50_data.index >= sell_date].index[0]
    except:
        adjusted_sell_date = nifty50_data[nifty50_data.index <= sell_date].index[-1]

    buy_price = nifty50_data[nifty50_data.index == adjusted_buy_date].values[0][0]
    sell_price = nifty50_data[nifty50_data.index == adjusted_sell_date].values[0][0]

    returns = (sell_price/buy_price)-1

    nifty_returns_1q_periods.append(returns)

# %%
nifty50 = round((statistics.mean(nifty_returns_1m_periods) + (((1+statistics.mean(nifty_returns_1q_periods))**(1/3))-1))/2,4)
nifty50
# Out:
# 0.0358

# %%
super_super_strategies = []

for strategy, returns in strategy_sell_price_dict.items():
    
    if (sum(returns)/len(returns)) > nifty50:
        print(strategy, (sum(returns)/len(returns)))
        super_super_strategies.append(strategy)

        strategy = ast.literal_eval(strategy)
        ss = math.ceil(strategy[0]/2)
        wa = strategy[1]
        atf = strategy[2]
        label = f'S{ss}-A{wa}-T{atf}'
        sns.kdeplot(returns, label=label)

# Adding a vertical dotted line at 0.05
plt.axvline(x=nifty50, color='r', linestyle='--', label='Nifty50')

# Adding titles and labels
title = 'Density Distribution of Portfolio Returns of Select Strategies from October 2023 to January 2024'
plt.title(title)
plt.xlabel('Monthly Returns')
plt.ylabel('Density')
plt.legend()

# Save and display the plot
plt.savefig(f'../backtesting_results/graphs_2/{title}.png', dpi=300)
plt.show()
# Out:
# (13, 7, 5) 0.0664125
# (9, 7, 5) 0.051662500000000014
# (9, 6, 5) 0.051662500000000014
# (9, 6, 7) 0.051662500000000014
# (5, 11, 3) 0.0628142857142857
# (5, 10, 3) 0.07130892857142856

# %%
def calculate_app_add_cost(dict1, buy, sell):
    num_stocks = len(dict1)
    total_turnover = buy+sell
    extra_cost = (16*num_stocks) + (math.ceil(total_turnover/(num_stocks*1000))*num_stocks)
    return math.ceil(extra_cost)

def add_columns_for_extra_charges(df):
    
    portfolio_list = list(df['portfolio'])
    
    selling_amount_list = list(df['investment_value'])
    buying_amount_list = [100000.00] + selling_amount_list[:-1]
    extra_cost_list = []

    for i in range(len(portfolio_list)):
        portfolio_dict = ast.literal_eval(portfolio_list[i])
        buy = buying_amount_list[i]
        sell = selling_amount_list[i]
        extra_cost = calculate_app_add_cost(portfolio_dict, buy, sell)
        extra_cost_list.append(extra_cost)
    
    return_list = []
    for i in range(len(portfolio_list)):
        returns = (selling_amount_list[i]/buying_amount_list[i])
        return_list.append(returns)

    new_selling_list = []

    for i in range(len(portfolio_list)):
        if i == 0:
            new_sell = selling_amount_list[0] - extra_cost_list[0]
            new_selling_list.append(round(new_sell,2))
        else:
            new_sell = (new_selling_list[i-1]*return_list[i]) - extra_cost_list[i]
            new_selling_list.append(round(new_sell,2))
    
    df['after_rebalancing_cost'] = new_selling_list
    
    return df

def add_columns_for_extra_charges_2(df):
    
    portfolio_list = list(df['portfolio'])
    
    selling_amount_list = list(df['investment_value_2'])
    buying_amount_list = [100000.00] + selling_amount_list[:-1]
    extra_cost_list = []

    for i in range(len(portfolio_list)):
        portfolio_dict = ast.literal_eval(portfolio_list[i])
        buy = buying_amount_list[i]
        sell = selling_amount_list[i]
        extra_cost = calculate_app_add_cost(portfolio_dict, buy, sell)
        extra_cost_list.append(extra_cost)
    
    return_list = []
    for i in range(len(portfolio_list)):
        returns = (selling_amount_list[i]/buying_amount_list[i])
        return_list.append(returns)

    new_selling_list = []

    for i in range(len(portfolio_list)):
        if i == 0:
            new_sell = selling_amount_list[0] - extra_cost_list[0]
            new_selling_list.append(round(new_sell,2))
        else:
            new_sell = (new_selling_list[i-1]*return_list[i]) - extra_cost_list[i]
            new_selling_list.append(round(new_sell,2))
    
    df['after_rebalancing_cost_2'] = new_selling_list
    
    return df

# %%
value_lists_list = []

# for strategy in strategies_selected:
for strategy in super_super_strategies:
    strategy = ast.literal_eval(strategy)
    stock_selection_method = strategy[0]
    weight_allocation_method = strategy[1]
    backtesting_version = strategy[2]
    file_path = f'../backtesting_results/version_{backtesting_version}/strategy_{stock_selection_method}_{weight_allocation_method}.csv'

    df = pd.read_csv(file_path)

    df = add_columns_for_extra_charges(df)

    value_list = [100000.00] + list(df['after rebalancing cost'])

    value_lists_list.append(value_list)

# %%
quarterly_dates = [datetime(year, month, 1) for year in range(2020, 2024) for month in [1, 4, 7, 10]]
formatted_quarterly_dates = [date.strftime('%Y-%m-%d') for date in quarterly_dates]

backtesting_buying_dates_for_1q_hold = formatted_quarterly_dates

len(backtesting_buying_dates_for_1q_hold)
# Out:
# 16

# %%
nifty_returns_1q_periods = []

for date in backtesting_buying_dates_for_1q_hold:
    buy_date = date
    sell_date = str(datetime.strptime(buy_date, '%Y-%m-%d') + relativedelta(months=3))[:10]

    adjusted_buy_date = nifty50_data[nifty50_data.index >= buy_date].index[0]
    try:
        adjusted_sell_date = nifty50_data[nifty50_data.index >= sell_date].index[0]
    except:
        adjusted_sell_date = nifty50_data[nifty50_data.index <= sell_date].index[-1]

    buy_price = nifty50_data[nifty50_data.index == adjusted_buy_date].values[0][0]
    sell_price = nifty50_data[nifty50_data.index == adjusted_sell_date].values[0][0]

    returns = (sell_price/buy_price)-1

    nifty_returns_1q_periods.append(returns)

# %%
nifty_investment_values = [100000.00]

for returns in nifty_returns_1q_periods:
    nifty_investment_values.append(nifty_investment_values[-1]*(1+returns))

len(nifty_investment_values), nifty_investment_values
# Out:
# (17,
#  [100000.0,
#   67751.28097424585,
#   85615.01994407963,
#   93715.98764877899,
#   115070.79827621588,
#   122038.5767237841,
#   128709.21403652779,
#   143911.76508311098,
#   144680.47788836443,
#   145047.8080751077,
#   129300.6345552021,
#   138619.7382259388,
#   149373.6853580956,
#   142811.82664682943,
#   158609.07680073872,
#   160301.66222039808,
#   178468.2978914426])

# %%
for i in quarterly_dates:
    print(str(i)[:7])
# Out:
# 2020-01
# 2020-04
# 2020-07
# 2020-10
# 2021-01
# 2021-04
# 2021-07
# 2021-10
# 2022-01
# 2022-04
# 2022-07
# 2022-10
# 2023-01
# 2023-04
# 2023-07
# 2023-10

# %%
data_lists = value_lists_list

quarterly_dates = pd.date_range(start='2019-10-01', periods=17, freq='Q')
monthly_dates = pd.date_range(start='2019-12-01', periods=49, freq='M')

# Plotting all sub-lists on the same plot
plt.figure(figsize=(8, 6))

for data in data_lists:
    if len(data) == 17:  # If data length matches quarterly data
        plt.plot(quarterly_dates, data, marker='.', linestyle='-')
    elif len(data) == 49:  # If data length matches monthly data
        plt.plot(monthly_dates, data, marker='.', linestyle='-')

plt.plot(quarterly_dates, nifty_investment_values, marker='|', linestyle='-')

title = 'Select Strategy Returns from 2020 to 2024'
plt.title(title)
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend(['S1','S2','S3','S4','S5','S6','Nifty50'])
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(f'../backtesting_results/graphs_2/{title}.png', dpi=300)
plt.show()

# %%
# strategy_performance_dict = load_json_to_dict('../data/last_4_months_results.json')
strategy_performance_dict = {}

for s in super_super_strategies:
    strategy_performance_dict[s] = super_strategies_performance_dict[s]

strategy_performance_dict
# Out:
# {'(13, 7, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'GET&D.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'RESPONIND.NS': 0.125},
#    'sell_price': 1258753.693977356},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'GET&D.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'TITAGARH.NS': 0.125},
#    'sell_price': 1373166.0194244385},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'BSE.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 1369829.3696289062},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HSCL.NS': 0.125},
#    'sell_price': 1392430.9512805939},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'HSCL.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 1455131.5842285156},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KAYNES.NS': 0.125,
#     'HSCL.NS': 0.125},
#    'sell_price': 1386232.1195983887},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 1374143.045829773},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'IRFC.NS': 0.125},
#    'sell_price': 1394078.945991516},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'JWL.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KAYNES.NS': 0.125},
#    'sell_price': 1334726.579284668},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'JWL.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'AGI.NS': 0.125},
#    'sell_price': 1281370.9916992188},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 1349802.7518997192},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MMTC.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 1268450.572090149},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125},
#    'sell_price': 1298827.7219791412},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 1246758.4564361572},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 1307450.3452033997},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'GET&D.NS': 0.125},
#    'sell_price': 1327964.2165412903},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'GET&D.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 1393399.0463428497},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 1211943.1135406494},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'ZENTEC.NS': 0.125},
#    'sell_price': 1207276.2380981445},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 1323234.9874897003},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 1338139.3559646606},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 1331436.7707519531},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'HBLPOWER.NS': 0.125},
#    'sell_price': 1328951.4781188965},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 1249758.692073822},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 1245287.1253204346},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'DBCORP.NS': 0.125},
#    'sell_price': 1269489.8354797363},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'ITI.NS': 0.125},
#    'sell_price': 1272909.8314704895},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'JWL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 1211240.1166114807},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 1157125.6831598282},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 1203485.6555175781},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'JINDALSAW.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125},
#    'sell_price': 1163266.2938194275},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JINDALSAW.NS': 0.125},
#    'sell_price': 1149907.4946975708},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 1120729.264656067},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'JWL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125},
#    'sell_price': 1106262.950668335},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JWL.NS': 0.125},
#    'sell_price': 1141219.7639884949},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'SUZLON.NS': 0.125,
#     'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'JWL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'EMIL.NS': 0.125},
#    'sell_price': 1145495.3959646225},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 1186924.2200603485},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 1156266.8629922867},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125},
#    'sell_price': 1186556.3710737228},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 1144395.422495842},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'TITAGARH.NS': 0.125,
#     'RTNPOWER.NS': 0.125},
#    'sell_price': 1139109.5254211426},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 1118248.9170913696},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'EMIL.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 1127159.4026947021},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'RTNPOWER.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 1132594.7285833359},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'SUZLON.NS': 0.125},
#    'sell_price': 1176878.716381073},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'SUZLON.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 1104621.453262329},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 1143783.567565918},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ITI.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'DBREALTY.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 1157359.550567627},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'ITI.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 984172.3431396484},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'KALYANKJIL.NS': 0.125,
#     'GMDCLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125},
#    'sell_price': 1006251.32721138},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'KALYANKJIL.NS': 0.125},
#    'sell_price': 1081900.538427353},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 1031344.3281478882},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'ITI.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 1006755.5024795532},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125,
#     'GMDCLTD.NS': 0.125},
#    'sell_price': 1069859.598197937},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'ITI.NS': 0.125,
#     'RECLTD.NS': 0.125},
#    'sell_price': 1083765.6195106506},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'BSE.NS': 0.125,
#     'IRFC.NS': 0.125,
#     'INOXWIND.NS': 0.125,
#     'HBLPOWER.NS': 0.125,
#     'ANANDRATHI.NS': 0.125,
#     'ITI.NS': 0.125,
#     'JPASSOCIAT.NS': 0.125,
#     'SUZLON.NS': 0.125},
#    'sell_price': 1074141.4483947754}],
#  '(9, 7, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 1096652.759918213},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 1107191.8618469238},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 1101893.8429870605},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 1109515.5454940796},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 1143930.7400283813},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1141456.4244995117},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 1233006.9546432495},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125},
#    'sell_price': 1128898.119419098},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'NATCOPHARM.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125},
#    'sell_price': 1178418.913269043},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 1115556.0778198242},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125},
#    'sell_price': 1179973.9366340637},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125},
#    'sell_price': 1057404.7522087097},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 1053242.6192016602},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 1161173.6413269043},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 1240748.5697174072},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 1274088.5104675293},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 1286100.6295471191},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 1336237.2532196045},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 1285862.1910476685},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125},
#    'sell_price': 1403128.9107666016},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 1302186.8875274658},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125},
#    'sell_price': 1304277.4789276123},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 1212485.0279846191},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 1319361.1544189453},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 1184039.6029968262},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125},
#    'sell_price': 1089581.7376098633},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 1144135.7684555054},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1079253.9943389893},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 1176742.7860565186},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1107226.4247131348},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 1277686.8799819946},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1129208.4473876953},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125},
#    'sell_price': 1348600.0664672852},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 1314162.1479187012},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 1336850.7105026245},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125},
#    'sell_price': 1235334.5191345215},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LINDEINDIA.NS': 0.125,
#     'LEMONTREE.NS': 0.125},
#    'sell_price': 1211038.6995391846},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 1038430.6832275391},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 1035978.7293548584},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 1151189.7940063477},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 1162640.6278076172},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125},
#    'sell_price': 1180498.573791504},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KIRLOSBROS.NS': 0.125,
#     'KFINTECH.NS': 0.125},
#    'sell_price': 1194675.2379760742},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125},
#    'sell_price': 1082357.0667800903},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KFINTECH.NS': 0.125,
#     'KKCL.NS': 0.125,
#     'KAYNES.NS': 0.125},
#    'sell_price': 1126945.4209594727},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125,
#     'KIRLOSENG.NS': 0.125,
#     'KFINTECH.NS': 0.125,
#     'KKCL.NS': 0.125},
#    'sell_price': 1100820.2404174805},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125,
#     'LTTS.NS': 0.125,
#     'L&TFH.NS': 0.125,
#     'KOLTEPATIL.NS': 0.125},
#    'sell_price': 1039662.9183654785},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125,
#     'LICHSGFIN.NS': 0.125},
#    'sell_price': 1087208.4566192627},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125},
#    'sell_price': 1045831.9468994141},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125},
#    'sell_price': 1191277.1089172363},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 1082946.7990875244},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 1076826.9775390625},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'MGL.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 1114689.8762207031},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LTIM.NS': 0.125},
#    'sell_price': 1044869.5125274658},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125},
#    'sell_price': 1040566.6910400391},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'LUPIN.NS': 0.125,
#     'LEMONTREE.NS': 0.125,
#     'LATENTVIEW.NS': 0.125,
#     'LT.NS': 0.125,
#     'LANDMARK.NS': 0.125},
#    'sell_price': 1044479.0319671631}],
#  '(9, 6, 5)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 1096652.759918213},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 1107191.8618469238},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MASTEK.NS': 0.125},
#    'sell_price': 1101893.8429870605},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 1109515.5454940796},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 1143930.7400283813},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1141456.4244995117},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 1233006.9546432495},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125},
#    'sell_price': 1128898.119419098},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'NATCOPHARM.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125},
#    'sell_price': 1178418.913269043},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125},
#    'sell_price': 1115556.0778198242},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MCX.NS': 0.125,
#     'BECTORFOOD.NS': 0.125,
#     'MPHASIS.NS': 0.125,
#     'MOTILALOFS.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125},
#    'sell_price': 1179973.9366340637},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MSUMI.NS': 0.125,
#     'MIDHANI.NS': 0.125,
#     'MINDACORP.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125},
#    'sell_price': 1057404.7522087097},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125},
#    'sell_price': 1053242.6192016602},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 1161173.6413269043},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 1240748.5697174072},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 1274088.5104675293},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARICO.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125},
#    'sell_price': 1286100.6295471191},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 1336237.2532196045},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'M&M.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 1285862.1910476685},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
#     'MRF.NS': 0.125,
#     'MOIL.NS': 0.125,
#     'MASFIN.NS': 0.125},
#    'sell_price': 1403128.9107666016},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MTARTECH.NS': 0.125},
#    'sell_price': 1302186.8875274658},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MANKIND.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125},
#    'sell_price': 1304277.4789276123},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 1212485.0279846191},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125},
#    'sell_price': 1319361.1544189453},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 1184039.6029968262},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125},
#    'sell_price': 1089581.7376098633},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MANKIND.NS': 0.125},
#    'sell_price': 1144135.7684555054},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MAYURUNIQ.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1079253.9943389893},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125},
#    'sell_price': 1176742.7860565186},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1107226.4247131348},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125},
#    'sell_price': 1277686.8799819946},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'METROPOLIS.NS': 0.125,
#     'METROBRAND.NS': 0.125,
#     'MAZDOCK.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MARKSANS.NS': 0.125},
#    'sell_price': 1129208.4473876953},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125},
#    'sell_price': 1348600.0664672852},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MFSL.NS': 0.125,
#     'MASTEK.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MAHLIFE.NS': 0.125},
#    'sell_price': 1314162.1479187012},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MARUTI.NS': 0.125,
#     'MRPL.NS': 0.125,
#     'MANAPPURAM.NS': 0.125,
#     'MANINFRA.NS': 0.125,
#     'MHRIL.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125},
#    'sell_price': 1336850.7105026245},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'360ONE.NS': 0.125,
#     'MAHSEAMLES.NS': 0.125,
#     'LODHA.NS': 0.125,
#     'MSTCLTD.NS': 0.125,
# ...
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAFARI.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1133631.4413452148},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'TI.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1091915.732788086},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1052756.8735351562},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAFARI.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1044982.2524414062},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAFARI.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1028875.1379699707},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAFARI.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1037826.763671875},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAFARI.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1035962.1584472656},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'MAHSEAMLES.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAFARI.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1018769.3020019531},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.19801980198019803,
#     'MAHSEAMLES.NS': 0.19801980198019803,
#     'APARINDS.NS': 0.19801980198019803,
#     'TITAGARH.NS': 0.19801980198019803,
#     'SAFARI.NS': 0.009900990099009901,
#     'JWL.NS': 0.19801980198019803},
#    'sell_price': 1077940.1889038086},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.2,
#     'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1120158.0908203125}],
#  '(5, 10, 3)': [{'buy_date': '2023-10-03 00:00:00',
#    'sell_date': '2024-01-03 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1223696.1046142578},
#   {'buy_date': '2023-10-04 00:00:00',
#    'sell_date': '2024-01-04 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.33333333333333337,
#     'JSL.NS': 0.33333333333333337,
#     'JWL.NS': 0.33333333333333337},
#    'sell_price': 1189645.0647888184},
#   {'buy_date': '2023-10-05 00:00:00',
#    'sell_date': '2024-01-05 00:00:00',
#    'portfolio': {'GRAVITA.NS': 0.25,
#     'SAFARI.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1174470.3239440918},
#   {'buy_date': '2023-10-06 00:00:00',
#    'sell_date': '2024-01-08 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1258535.6133422852},
#   {'buy_date': '2023-10-09 00:00:00',
#    'sell_date': '2024-01-09 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1274848.043395996},
#   {'buy_date': '2023-10-10 00:00:00',
#    'sell_date': '2024-01-10 00:00:00',
#    'portfolio': {'JSL.NS': 0.2,
#     'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1278882.6491699219},
#   {'buy_date': '2023-10-11 00:00:00',
#    'sell_date': '2024-01-11 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'JWL.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1218250.087463379},
#   {'buy_date': '2023-10-12 00:00:00',
#    'sell_date': '2024-01-12 00:00:00',
#    'portfolio': {'JWL.NS': 0.2,
#     'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAKSOFT.NS': 0.2},
#    'sell_price': 1174004.4702148438},
#   {'buy_date': '2023-10-13 00:00:00',
#    'sell_date': '2024-01-15 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1242502.7431030273},
#   {'buy_date': '2023-10-16 00:00:00',
#    'sell_date': '2024-01-16 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'SAFARI.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1197017.5545043945},
#   {'buy_date': '2023-10-17 00:00:00',
#    'sell_date': '2024-01-17 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1283960.1784057617},
#   {'buy_date': '2023-10-18 00:00:00',
#    'sell_date': '2024-01-18 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1250763.954650879},
#   {'buy_date': '2023-10-19 00:00:00',
#    'sell_date': '2024-01-19 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1290162.073791504},
#   {'buy_date': '2023-10-20 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'SAFARI.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1232476.2680358887},
#   {'buy_date': '2023-10-23 00:00:00',
#    'sell_date': '2024-01-23 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25},
#    'sell_price': 1319252.4490356445},
#   {'buy_date': '2023-10-25 00:00:00',
#    'sell_date': '2024-01-25 00:00:00',
#    'portfolio': {'JSL.NS': 0.2,
#     'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1363592.9206542969},
#   {'buy_date': '2023-10-26 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'FACT.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1378223.2415771484},
#   {'buy_date': '2023-10-27 00:00:00',
#    'sell_date': '2024-01-29 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'FACT.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1414981.5487670898},
#   {'buy_date': '2023-10-30 00:00:00',
#    'sell_date': '2024-01-30 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'JSL.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1387332.657775879},
#   {'buy_date': '2023-10-31 00:00:00',
#    'sell_date': '2024-01-31 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1387009.6135559082},
#   {'buy_date': '2023-11-01 00:00:00',
#    'sell_date': '2024-02-01 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'PFC.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1482595.5329742432},
#   {'buy_date': '2023-11-02 00:00:00',
#    'sell_date': '2024-02-02 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1395947.3216552734},
#   {'buy_date': '2023-11-03 00:00:00',
#    'sell_date': '2024-02-05 00:00:00',
#    'portfolio': {'JSL.NS': 0.2,
#     'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1368537.855102539},
#   {'buy_date': '2023-11-06 00:00:00',
#    'sell_date': '2024-02-06 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.33333333333333337,
#     'ANANDRATHI.NS': 0.33333333333333337,
#     'JWL.NS': 0.33333333333333337},
#    'sell_price': 1404819.5705566406},
#   {'buy_date': '2023-11-07 00:00:00',
#    'sell_date': '2024-02-07 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.19801980198019803,
#     'APARINDS.NS': 0.19801980198019803,
#     'IONEXCHANG.NS': 0.19801980198019803,
#     'ANANDRATHI.NS': 0.19801980198019803,
#     'JWL.NS': 0.19801980198019803,
#     'PRICOLLTD.NS': 0.009900990099009901},
#    'sell_price': 1297537.9191894531},
#   {'buy_date': '2023-11-08 00:00:00',
#    'sell_date': '2024-02-08 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'PFC.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1437868.69140625},
#   {'buy_date': '2023-11-09 00:00:00',
#    'sell_date': '2024-02-09 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'FACT.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1273186.1057128906},
#   {'buy_date': '2023-11-10 00:00:00',
#    'sell_date': '2024-02-12 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'FACT.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1216859.0179138184},
#   {'buy_date': '2023-11-13 00:00:00',
#    'sell_date': '2024-02-13 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'FACT.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1222142.8964233398},
#   {'buy_date': '2023-11-15 00:00:00',
#    'sell_date': '2024-02-15 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1261950.4060058594},
#   {'buy_date': '2023-11-16 00:00:00',
#    'sell_date': '2024-02-16 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1287738.6676940918},
#   {'buy_date': '2023-11-17 00:00:00',
#    'sell_date': '2024-02-19 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1239932.8516235352},
#   {'buy_date': '2023-11-20 00:00:00',
#    'sell_date': '2024-02-20 00:00:00',
#    'portfolio': {'JWL.NS': 0.33333333333333337,
#     'ANANDRATHI.NS': 0.33333333333333337,
#     'TITAGARH.NS': 0.33333333333333337},
#    'sell_price': 1249131.1763916016},
#   {'buy_date': '2023-11-21 00:00:00',
#    'sell_date': '2024-02-21 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1181475.4041748047},
#   {'buy_date': '2023-11-22 00:00:00',
#    'sell_date': '2024-02-22 00:00:00',
#    'portfolio': {'RECLTD.NS': 0.2,
#     'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1233402.7589111328},
#   {'buy_date': '2023-11-23 00:00:00',
#    'sell_date': '2024-02-23 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25},
#    'sell_price': 1196617.494354248},
#   {'buy_date': '2023-11-24 00:00:00',
#    'sell_date': '2024-02-26 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.19801980198019803,
#     'HBLPOWER.NS': 0.009900990099009901,
#     'APARINDS.NS': 0.19801980198019803,
#     'RECLTD.NS': 0.19801980198019803,
#     'ANANDRATHI.NS': 0.19801980198019803,
#     'JWL.NS': 0.19801980198019803},
#    'sell_price': 1214221.5845031738},
#   {'buy_date': '2023-11-28 00:00:00',
#    'sell_date': '2024-02-28 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.19801980198019803,
#     'SAFARI.NS': 0.19801980198019803,
#     'APARINDS.NS': 0.19801980198019803,
#     'ACE.NS': 0.009900990099009901,
#     'ANANDRATHI.NS': 0.19801980198019803,
#     'TI.NS': 0.19801980198019803},
#    'sell_price': 1064827.0308685303},
#   {'buy_date': '2023-11-29 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.33333333333333337,
#     'APARINDS.NS': 0.33333333333333337,
#     'TITAGARH.NS': 0.33333333333333337},
#    'sell_price': 1187759.745300293},
#   {'buy_date': '2023-11-30 00:00:00',
#    'sell_date': '2024-02-29 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'PFC.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1159285.715209961},
#   {'buy_date': '2023-12-01 00:00:00',
#    'sell_date': '2024-03-01 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'PFC.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1145490.6014404297},
#   {'buy_date': '2023-12-04 00:00:00',
#    'sell_date': '2024-03-04 00:00:00',
#    'portfolio': {'PFC.NS': 0.25,
#     'JWL.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1072448.5714416504},
#   {'buy_date': '2023-12-05 00:00:00',
#    'sell_date': '2024-03-05 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1157111.8196411133},
#   {'buy_date': '2023-12-06 00:00:00',
#    'sell_date': '2024-03-06 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'PFC.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1141942.892211914},
#   {'buy_date': '2023-12-07 00:00:00',
#    'sell_date': '2024-03-07 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'JWL.NS': 0.25},
#    'sell_price': 1178938.3893432617},
#   {'buy_date': '2023-12-08 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.2,
#     'TITAGARH.NS': 0.2,
#     'PFC.NS': 0.2,
#     'APARINDS.NS': 0.2,
#     'JWL.NS': 0.2},
#    'sell_price': 1182941.448059082},
#   {'buy_date': '2023-12-11 00:00:00',
#    'sell_date': '2024-03-11 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1181281.7642822266},
#   {'buy_date': '2023-12-12 00:00:00',
#    'sell_date': '2024-03-12 00:00:00',
#    'portfolio': {'ANANDRATHI.NS': 0.33333333333333337,
#     'APARINDS.NS': 0.33333333333333337,
#     'TITAGARH.NS': 0.33333333333333337},
#    'sell_price': 1195621.9931640625},
#   {'buy_date': '2023-12-13 00:00:00',
#    'sell_date': '2024-03-13 00:00:00',
#    'portfolio': {'SAFARI.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1052756.8735351562},
#   {'buy_date': '2023-12-14 00:00:00',
#    'sell_date': '2024-03-14 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1109608.208618164},
#   {'buy_date': '2023-12-15 00:00:00',
#    'sell_date': '2024-03-15 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1087967.279296875},
#   {'buy_date': '2023-12-18 00:00:00',
#    'sell_date': '2024-03-18 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1099269.7717285156},
#   {'buy_date': '2023-12-19 00:00:00',
#    'sell_date': '2024-03-19 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1099994.710571289},
#   {'buy_date': '2023-12-20 00:00:00',
#    'sell_date': '2024-03-20 00:00:00',
#    'portfolio': {'JWL.NS': 0.33333333333333337,
#     'ANANDRATHI.NS': 0.33333333333333337,
#     'TITAGARH.NS': 0.33333333333333337},
#    'sell_price': 1116052.3943481445},
#   {'buy_date': '2023-12-21 00:00:00',
#    'sell_date': '2024-03-21 00:00:00',
#    'portfolio': {'JWL.NS': 0.25,
#     'ANANDRATHI.NS': 0.25,
#     'APARINDS.NS': 0.25,
#     'TITAGARH.NS': 0.25},
#    'sell_price': 1120991.9385986328},
#   {'buy_date': '2023-12-22 00:00:00',
#    'sell_date': '2024-03-22 00:00:00',
#    'portfolio': {'TITAGARH.NS': 0.19801980198019803,
#     'SAFARI.NS': 0.009900990099009901,
#     'APARINDS.NS': 0.19801980198019803,
#     'RECLTD.NS': 0.19801980198019803,
#     'ANANDRATHI.NS': 0.19801980198019803,
#     'JWL.NS': 0.19801980198019803},
#    'sell_price': 1117916.9407958984}]}

# %%
for amount in [1000, 10000, 100000, 1000000]:
    
    plt.figure(figsize=(10, 8))

    for strategy, results in strategy_performance_dict.items():
        for result in results:
            buying_date = result['buy_date'][:10]
            selling_date = result['sell_date'][:10]
            portfolio_weights = result['portfolio']

            adjusted_buy_date = all_stocks_df[all_stocks_df.index <= buying_date].index[-1]
            adjusted_sell_date = all_stocks_df[all_stocks_df.index <= selling_date].index[-1]
        
            final_shares, price_dict, actual_investment = calculate_shares_to_buy_with_prices(portfolio_weights, all_stocks_df, adjusted_buy_date, amount, True)
            
            profit = 0
            for stock_symbol, number_of_shares in final_shares.items():
                buy_amount = (all_stocks_df[stock_symbol].loc[adjusted_buy_date] * number_of_shares)
                sell_amount = (all_stocks_df[stock_symbol].loc[adjusted_sell_date] * number_of_shares)
                profit += sell_amount-buy_amount
            
            result['sell_price'] = amount + profit

    strategy_sell_price_dict_2 = {}
    for strategy, portfolios in strategy_performance_dict.items():
        strategy_sell_price_dict_2[strategy] = []
        if len(portfolios) == 65:
            for portfolio in portfolios:
                strategy_sell_price_dict_2[strategy].append(round((portfolio['sell_price']/amount)-1,4))
        else:
            for portfolio in portfolios:
                return_quarterly = (portfolio['sell_price']/amount)-1
                strategy_sell_price_dict_2[strategy].append(round(((1+return_quarterly)**(1/3))-1,4))

    for k,v in strategy_sell_price_dict_2.items():
        print(k, round(sum(v)/len(v),4))

    for strategy, returns in strategy_sell_price_dict_2.items():
        strategy = ast.literal_eval(strategy)
        ss = math.ceil(strategy[0]/2)
        wa = strategy[1]
        atf = strategy[2]
        label = f'S{ss}-A{wa}-T{atf}'
        sns.kdeplot(returns, label=label)

    # Adding a vertical dotted line at 0.05
    plt.axvline(x=nifty50, color='r', linestyle='--', label='Nifty50')
    # Adding titles and labels
    title = f'Density Distribution of Portfolio Returns of Select Strategies from Oct 2023 to Jan 2024 (With INR {amount})'
    plt.title(title)
    plt.xlabel('Monthly Returns')
    plt.ylabel('Density')
    plt.legend()

    # Save and display the plot
    plt.savefig(f'../backtesting_results/graphs_2/{title}.png', dpi=300)
    plt.show()
# Out:
# (13, 7, 5) 0.0675
# (9, 7, 5) 0.0863
# (9, 6, 5) 0.0863
# (9, 6, 7) 0.0863
# (5, 11, 3) 0.0088
# (5, 10, 3) 0.0183
# (13, 7, 5) 0.0645
# (9, 7, 5) 0.0536
# (9, 6, 5) 0.0536
# (9, 6, 7) 0.0536
# (5, 11, 3) 0.0488
# (5, 10, 3) 0.056
# (13, 7, 5) 0.0657
# (9, 7, 5) 0.0503
# (9, 6, 5) 0.0503
# (9, 6, 7) 0.0503
# (5, 11, 3) 0.0609
# (5, 10, 3) 0.0695
# (13, 7, 5) 0.0663
# (9, 7, 5) 0.0515
# (9, 6, 5) 0.0515
# (9, 6, 7) 0.0515
# (5, 11, 3) 0.0626
# (5, 10, 3) 0.0711

# %%
value_lists_list_2 = []

for strategy in super_super_strategies:

    strategy = ast.literal_eval(strategy)
    
    init_invt_amt_li = []
    initial_investment = 100000

    stock_selection_method = strategy[0]
    weight_allocation_method = strategy[1]
    backtesting_version = strategy[2]
    file_path = f'../backtesting_results/version_{backtesting_version}/strategy_{stock_selection_method}_{weight_allocation_method}.csv'

    df = pd.read_csv(file_path)

    for i in range(len(df)):
        adjusted_buy_date = all_stocks_df[all_stocks_df.index <= df.iloc[i]['buy_date']].index[-1]
        adjusted_sell_date = all_stocks_df[all_stocks_df.index <= df.iloc[i]['sell_date']].index[-1]
        portfolio_weights = ast.literal_eval(df.iloc[i]['portfolio'])

        final_shares, price_dict, actual_investment = calculate_shares_to_buy_with_prices(portfolio_weights, all_stocks_df, adjusted_buy_date, initial_investment, True)

        profit = 0
        for stock_symbol, number_of_shares in final_shares.items():
            buy_amount = (all_stocks_df[stock_symbol].loc[adjusted_buy_date] * number_of_shares)
            sell_amount = (all_stocks_df[stock_symbol].loc[adjusted_sell_date] * number_of_shares)
            profit += sell_amount-buy_amount

        initial_investment += profit
        init_invt_amt_li.append(round(initial_investment,2))
    
    df['investment_value_2'] = init_invt_amt_li
    
    df = add_columns_for_extra_charges_2(df)

    value_list = [100000.00] + list(df['after_rebalancing_cost_2'])

    value_lists_list_2.append(value_list)

# %%
data_lists = value_lists_list_2

quarterly_dates = pd.date_range(start='2019-10-01', periods=17, freq='Q')
monthly_dates = pd.date_range(start='2019-12-01', periods=49, freq='M')

# Plotting all sub-lists on the same plot
plt.figure(figsize=(8, 6))

for data in data_lists:
    if len(data) == 17:  # If data length matches quarterly data
        plt.plot(quarterly_dates, data, marker='.', linestyle='-')
    elif len(data) == 49:  # If data length matches monthly data
        plt.plot(monthly_dates, data, marker='.', linestyle='-')

plt.plot(quarterly_dates, nifty_investment_values, marker='|', linestyle='-')

title = 'Select Strategy Returns from 2020 to 2024 (Version 2)'
plt.title(title)
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend(['S1','S2','S3','S4','S5','S6','Nifty50'])
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(f'../backtesting_results/graphs_2/{title}.png', dpi=300)
plt.show()

# %%
data_lists = value_lists_list + value_lists_list_2

quarterly_dates = pd.date_range(start='2019-10-01', periods=17, freq='Q')
monthly_dates = pd.date_range(start='2019-12-01', periods=49, freq='M')

# Plotting all sub-lists on the same plot
plt.figure(figsize=(8, 6))

for data in data_lists:
    if len(data) == 17:  # If data length matches quarterly data
        plt.plot(quarterly_dates, data, marker='.', linestyle='-')
    elif len(data) == 49:  # If data length matches monthly data
        plt.plot(monthly_dates, data, marker='.', linestyle='-')

plt.plot(quarterly_dates, nifty_investment_values, marker='|', linestyle='-')

title = 'Select Strategy Returns from 2020 to 2024 (Both)'
plt.title(title)
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend(['S1','S2','S3','S4','S5','S6','S1(V2)','S2(V2)','S3(V2)','S4(V2)','S5(V2)','S6(V2)','Nifty50'])
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig(f'../backtesting_results/graphs_2/{title}.png', dpi=300)
plt.show()

# %%
for list_ in value_lists_list:
    return_4y = round(list_[-1]/list_[0],2)
    annualized_return = round((return_4y**(1/4))-1,4)
    print(annualized_return)
# Out:
# 0.7556
# 0.2783
# 0.2783
# 0.315
# 0.8391
# 0.8689

# %%
for list_ in value_lists_list_2:
    return_4y = round(list_[-1]/list_[0],2)
    annualized_return = round((return_4y**(1/4))-1,4)
    print(annualized_return)
# Out:
# 0.8132
# 0.2649
# 0.2649
# 0.3027
# 0.8391
# 0.8631

# %%
nifty_investment_values
# Out:
# [100000.0,
#  67751.28097424585,
#  85615.01994407963,
#  93715.98764877899,
#  115070.79827621588,
#  122038.5767237841,
#  128709.21403652779,
#  143911.76508311098,
#  144680.47788836443,
#  145047.8080751077,
#  129300.6345552021,
#  138619.7382259388,
#  149373.6853580956,
#  142811.82664682943,
#  158609.07680073872,
#  160301.66222039808,
#  178468.2978914426]

# %%
return_4y = round(nifty_investment_values[-1]/nifty_investment_values[0],2)
annualized_return = round((return_4y**(1/4))-1,4)
annualized_return
# Out:
# 0.1551
